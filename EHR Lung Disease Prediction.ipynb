# %%
# !pip install xgboost --quiet

# %%
###  Data Extraction

# %%
# Cell 1: Imports and Settings
import pandas as pd
from datetime import timedelta

# %%
# Cell 2: Define file paths and load the datasets
base = r'C:\Users\yanis\Downloads\Compressed\synthea-patient-pop1-csv'
patients_path   = f"{base}\\patients.csv"
conditions_path = f"{base}\\conditions.csv"
encounters_path = f"{base}\\encounters.csv"
obs_path        = f"{base}\\observations.csv"

patients = pd.read_csv(
    patients_path,
    parse_dates=['BIRTHDATE', 'DEATHDATE']
)
conditions = pd.read_csv(
    conditions_path,
    parse_dates=['START', 'STOP']
)
encounters = pd.read_csv(
    encounters_path,
    parse_dates=['START', 'STOP']
)

# %%
# Cell 3: Preview raw data
print("Patients sample:")
print(patients.head(), "\n")
print("Conditions sample:")
print(conditions.head(), "\n")
print("Encounters sample:")
print(encounters.head(), "\n")
# Out:
# Patients sample:
#                                      Id  BIRTHDATE  DEATHDATE          SSN  \
# 0  5605b66b-e92d-c16c-1b83-b8bf7040d51f 1977-03-19        NaT  999-94-9633
# 1  c06a2ab3-c3b1-a3d0-7c12-262a12c6885e 1936-07-03        NaT  999-76-5032
# 2  6e5ae27c-8038-7988-e2c0-25a103f01bfa 1940-02-19        NaT  999-83-7940
# 3  94d39619-8e17-d248-41b3-9ec1f2d031b2 1954-11-08 2010-01-10  999-84-3708
# 4  23832f5d-e045-2541-1626-a65dce9bbcf7 1972-04-13        NaT  999-89-5858
#
#      DRIVERS    PASSPORT PREFIX           FIRST           LAST SUFFIX  ...  \
# 0  S99930485  X51431379X   Mrs.       Nikita578      Erdman779    NaN  ...
# 1  S99927160  X37795263X    Mr.  Miguel Ángel46     Atencio773    NaN  ...
# 2  S99932661  X36822066X    Mr.         Zane918  Hodkiewicz467    NaN  ...
# 3  S99923522  X49705907X    Mr.       Emmett200     Collins926    NaN  ...
# 4  S99939931  X88479701X   Mrs.        Magan944       Green467    NaN  ...
#
#                         BIRTHPLACE                         ADDRESS  \
# 0     Wakefield  Massachusetts  US      510 Little Station Unit 69
# 1           San Jose  San Jose  CR      1022 Hermann Quay Suite 79
# 2     Brookline  Massachusetts  US             747 Conn Throughway
# 3  Baldwinville  Massachusetts  US       675 Ortiz Mission Unit 59
# 4     Worcester  Massachusetts  US  427 Jakubowski Viaduct Unit 76
#
#           CITY          STATE           COUNTY     ZIP        LAT        LON  \
# 0       Quincy  Massachusetts   Norfolk County  2186.0  42.290937 -70.975503
# 1  Springfield  Massachusetts   Hampden County  1118.0  42.119725 -72.529805
# 2       Boston  Massachusetts   Suffolk County  2135.0  42.308831 -71.063162
# 3      Hingham  Massachusetts  Plymouth County  2043.0  42.257452 -70.848673
# 4    Edgartown  Massachusetts     Dukes County     NaN  41.364910 -70.519177
#
#   HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE
# 0        1.382106e+06         390849.2625
# 1        2.118565e+06         108146.8010
# 2        2.007909e+06         333884.4150
# 3        2.637311e+06         149574.3525
# 4        1.859584e+06          69524.1780
#
# [5 rows x 25 columns]
#
# Conditions sample:
#        START       STOP                               PATIENT  \
# 0 1988-04-02        NaT  5605b66b-e92d-c16c-1b83-b8bf7040d51f
# 1 1954-08-27        NaT  c06a2ab3-c3b1-a3d0-7c12-262a12c6885e
# 2 1954-08-27 1955-09-02  c06a2ab3-c3b1-a3d0-7c12-262a12c6885e
# 3 1954-08-27 1958-09-05  c06a2ab3-c3b1-a3d0-7c12-262a12c6885e
# 4 1955-09-02 1958-09-05  c06a2ab3-c3b1-a3d0-7c12-262a12c6885e
#
#                               ENCOUNTER       CODE  \
# 0  be3e07a4-00ea-4e1f-6e5c-32620712d7e1  162864005
# 1  3e2dd16e-a2f0-6467-1950-84ef2e834c73  224295006
# 2  3e2dd16e-a2f0-6467-1950-84ef2e834c73  160903007
# 3  3e2dd16e-a2f0-6467-1950-84ef2e834c73  422650009
# 4  2f572a12-0189-7eba-f11c-d308deb08435  160903007
#
#                                         DESCRIPTION
# 0           Body mass index 30+ - obesity (finding)
# 1  Only received primary school education (finding)
# 2                    Full-time employment (finding)
# 3                        Social isolation (finding)
# 4                    Full-time employment (finding)
#
# Encounters sample:
#                                      Id                     START  \
# 0  be3e07a4-00ea-4e1f-6e5c-32620712d7e1 1988-04-02 22:07:23+00:00
# 1  8ac8a7d4-f24d-20a8-dfa1-812a94f726e6 1991-04-20 22:07:23+00:00
# 2  3e2dd16e-a2f0-6467-1950-84ef2e834c73 1954-08-28 05:14:39+00:00
# 3  2f572a12-0189-7eba-f11c-d308deb08435 1955-09-03 05:14:39+00:00
# 4  c71f66d6-d085-b323-e1b7-8963e510d4db 1958-09-06 05:14:39+00:00
#
#                        STOP                               PATIENT  \
# 0 1988-04-02 22:22:23+00:00  5605b66b-e92d-c16c-1b83-b8bf7040d51f
# 1 1991-04-20 22:22:23+00:00  5605b66b-e92d-c16c-1b83-b8bf7040d51f
# 2 1954-08-28 05:29:39+00:00  c06a2ab3-c3b1-a3d0-7c12-262a12c6885e
# 3 1955-09-03 05:29:39+00:00  c06a2ab3-c3b1-a3d0-7c12-262a12c6885e
# 4 1958-09-06 05:29:39+00:00  c06a2ab3-c3b1-a3d0-7c12-262a12c6885e
#
#                            ORGANIZATION                              PROVIDER  \
# 0  0aef5bb7-af50-38c6-934a-8f5a25d81fd1  1f1d9cdf-e594-3527-8f86-6ac68b0a5d30
# 1  0aef5bb7-af50-38c6-934a-8f5a25d81fd1  1f1d9cdf-e594-3527-8f86-6ac68b0a5d30
# 2  5e91d1b8-0e6e-32d4-93df-449c6c624492  7f9f32d1-4426-3277-9fbd-8ae3855df313
# 3  5e91d1b8-0e6e-32d4-93df-449c6c624492  7f9f32d1-4426-3277-9fbd-8ae3855df313
# 4  5e91d1b8-0e6e-32d4-93df-449c6c624492  7f9f32d1-4426-3277-9fbd-8ae3855df313
#
#                                   PAYER ENCOUNTERCLASS       CODE  \
# 0  42c4fca7-f8a9-3cd1-982a-dd9751bf3e2a       wellness  410620009
# 1  d47b3510-2895-3b70-9897-342d681c769d       wellness  410620009
# 2  047f6ec3-6215-35eb-9608-f9dda363a44c       wellness  162673000
# 3  047f6ec3-6215-35eb-9608-f9dda363a44c       wellness  162673000
# 4  d47b3510-2895-3b70-9897-342d681c769d       wellness  162673000
#
#                                   DESCRIPTION  BASE_ENCOUNTER_COST  \
# 0                Well child visit (procedure)                136.8
# 1                Well child visit (procedure)                136.8
# 2  General examination of patient (procedure)                136.8
# 3  General examination of patient (procedure)                136.8
# 4  General examination of patient (procedure)                136.8
#
#    TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE REASONDESCRIPTION
# 0            347.38             0.0         NaN               NaN
# 1           1157.88             0.0         NaN               NaN
# 2            704.20             0.0         NaN               NaN
# 3           1266.54             0.0         NaN               NaN
# 4           1491.93             0.0         NaN               NaN

# %%
# Cell 4: Label lung-related conditions
snomed_codes = ['233604007', '195967001', '13645005']  # pneumonia, asthma, COPD
keywords = ['pneumonia', 'chronic obstructive', 'COPD', 'asthma']
pattern = '|'.join(keywords)
conditions['lung_label'] = (
    conditions['CODE'].astype(str).isin(snomed_codes)
    | conditions['DESCRIPTION'].str.contains(pattern, case=False, na=False)
)

# %%
# Cell 5: Inspect flagged lung-condition records
lung_positive = conditions[conditions['lung_label']]
print("Flagged lung conditions:")
print(lung_positive[['PATIENT','CODE','DESCRIPTION','START']].head(), "\n")
# Out:
# Flagged lung conditions:
#                                    PATIENT       CODE           DESCRIPTION  \
# 1008  ad362b64-31b4-8fa3-c760-38d0e5cacc1c  233604007             Pneumonia
# 1216  febefd51-6130-5e0e-34ed-2ccce47be271  233604007  Pneumonia (disorder)
# 1416  a4e89ca1-2d08-a775-cd47-526bbc80f6ea  233604007             Pneumonia
# 2159  2853ca5a-7862-68c8-07d1-3d7fa2d6ae27  233604007             Pneumonia
# 2334  84a69a69-4309-1549-de32-083332b13d56  195967001                Asthma
#
#           START
# 1008 2012-12-12
# 1216 2020-11-06
# 1416 2017-04-24
# 2159 2017-07-20
# 2334 1997-01-20

# %%
# Cell 6: Aggregate per-patient labels and first-positive condition
patients.rename(columns={'Id':'patient_id'}, inplace=True)
cohort = (
    conditions
    .groupby('PATIENT', as_index=False)['lung_label']
    .max()
    .rename(columns={'PATIENT':'patient_id'})
)
first_lung = (
    conditions[conditions['lung_label']]
    .sort_values(['PATIENT','START'])
    .groupby('PATIENT', as_index=False)
    .first()[['PATIENT','CODE','DESCRIPTION']]
    .rename(columns={
        'PATIENT':'patient_id',
        'CODE':'first_lung_code',
        'DESCRIPTION':'first_lung_description'
    })
)
cohort = cohort.merge(first_lung, on='patient_id', how='left')
cohort = cohort.merge(patients, on='patient_id', how='left')

# %%
# Cell 7: Save base cohort
cohort.to_csv('cohort.csv', index=False)
print("Cohort saved to cohort.csv")
print(cohort.head(), "\n")
# Out:
# Cohort saved to cohort.csv
#                              patient_id  lung_label  first_lung_code  \
# 0  0007b281-7eb0-f2b2-d12a-3fc1e2f7e3e2       False              NaN
# 1  0007efd3-c50d-7e51-6a30-8dc08d4269fc        True      233604007.0
# 2  000eba84-0d5c-2657-0b5e-0c70f2f746c2       False              NaN
# 3  000f23c8-470d-babb-5fda-2b13c6c54e80       False              NaN
# 4  0011c542-8a54-27c3-59d6-1575d265210e       False              NaN
#
#   first_lung_description  BIRTHDATE  DEATHDATE          SSN    DRIVERS  \
# 0                    NaN 1950-01-27 2001-12-14  999-38-9527  S99999004
# 1   Pneumonia (disorder) 1963-11-25        NaT  999-91-3685  S99920576
# 2                    NaN 1929-04-06        NaT  999-18-7950  S99957211
# 3                    NaN 1938-07-22        NaT  999-18-9795  S99962765
# 4                    NaN 1965-02-10        NaT  999-13-2355  S99966163
#
#      PASSPORT PREFIX  ...                           BIRTHPLACE  \
# 0  X36466268X    Ms.  ...             Salem  Massachusetts  US
# 1  X89812792X    Mr.  ...            Newton  Massachusetts  US
# 2  X41011359X    Mr.  ...  West Springfield  Massachusetts  US
# 3  X28290507X    Mr.  ...       Dennis Port  Massachusetts  US
# 4  X69504941X    Mr.  ...            Boston  Massachusetts  US
#
#                           ADDRESS         CITY          STATE  \
# 0                171 Larkin Track    Tewksbury  Massachusetts
# 1             698 Jacobson Hollow    Haverhill  Massachusetts
# 2       902 Dibbert Common Apt 67      Dighton  Massachusetts
# 3  154 Wilkinson Underpass Apt 28     Chicopee  Massachusetts
# 4         1004 Will Track Unit 53  Marlborough  Massachusetts
#
#              COUNTY     ZIP        LAT        LON HEALTHCARE_EXPENSES  \
# 0  Middlesex County     NaN  42.609845 -71.229009        1.853619e+06
# 1      Essex County  1830.0  42.754621 -71.089943        1.500499e+06
# 2    Bristol County     NaN  41.798910 -71.196704        3.008311e+06
# 3    Hampden County  1020.0  42.156924 -72.530148        2.051432e+06
# 4  Middlesex County     NaN  42.309669 -71.576196        2.009692e+06
#
#   HEALTHCARE_COVERAGE
# 0         606491.7320
# 1           4387.4550
# 2         297474.4500
# 3         126217.7930
# 4          91625.4225
#
# [5 rows x 28 columns]

# %%
# Cell 7: DEBUG – Inspect cohort after merging labels & demographics
print("➤ Cohort shape:", cohort.shape)
print("\n➤ Lung_label counts:\n", cohort['lung_label'].value_counts(dropna=False), "\n")
print("➤ Sample cohort rows:\n", cohort.head(), "\n")
# Out:
# ➤ Cohort shape: (15354, 28)
#
# ➤ Lung_label counts:
#  lung_label
# False    14126
# True      1228
# Name: count, dtype: int64
#
# ➤ Sample cohort rows:
#                               patient_id  lung_label  first_lung_code  \
# 0  0007b281-7eb0-f2b2-d12a-3fc1e2f7e3e2       False              NaN
# 1  0007efd3-c50d-7e51-6a30-8dc08d4269fc        True      233604007.0
# 2  000eba84-0d5c-2657-0b5e-0c70f2f746c2       False              NaN
# 3  000f23c8-470d-babb-5fda-2b13c6c54e80       False              NaN
# 4  0011c542-8a54-27c3-59d6-1575d265210e       False              NaN
#
#   first_lung_description  BIRTHDATE  DEATHDATE          SSN    DRIVERS  \
# 0                    NaN 1950-01-27 2001-12-14  999-38-9527  S99999004
# 1   Pneumonia (disorder) 1963-11-25        NaT  999-91-3685  S99920576
# 2                    NaN 1929-04-06        NaT  999-18-7950  S99957211
# 3                    NaN 1938-07-22        NaT  999-18-9795  S99962765
# 4                    NaN 1965-02-10        NaT  999-13-2355  S99966163
#
#      PASSPORT PREFIX  ...                           BIRTHPLACE  \
# 0  X36466268X    Ms.  ...             Salem  Massachusetts  US
# 1  X89812792X    Mr.  ...            Newton  Massachusetts  US
# 2  X41011359X    Mr.  ...  West Springfield  Massachusetts  US
# 3  X28290507X    Mr.  ...       Dennis Port  Massachusetts  US
# 4  X69504941X    Mr.  ...            Boston  Massachusetts  US
#
#                           ADDRESS         CITY          STATE  \
# 0                171 Larkin Track    Tewksbury  Massachusetts
# 1             698 Jacobson Hollow    Haverhill  Massachusetts
# 2       902 Dibbert Common Apt 67      Dighton  Massachusetts
# 3  154 Wilkinson Underpass Apt 28     Chicopee  Massachusetts
# 4         1004 Will Track Unit 53  Marlborough  Massachusetts
#
#              COUNTY     ZIP        LAT        LON HEALTHCARE_EXPENSES  \
# 0  Middlesex County     NaN  42.609845 -71.229009        1.853619e+06
# 1      Essex County  1830.0  42.754621 -71.089943        1.500499e+06
# 2    Bristol County     NaN  41.798910 -71.196704        3.008311e+06
# 3    Hampden County  1020.0  42.156924 -72.530148        2.051432e+06
# 4  Middlesex County     NaN  42.309669 -71.576196        2.009692e+06
#
#   HEALTHCARE_COVERAGE
# 0         606491.7320
# 1           4387.4550
# 2         297474.4500
# 3         126217.7930
# 4          91625.4225
#
# [5 rows x 28 columns]

# %%
# Cell 8: Feature Engineering — Compute age at first encounter and current/at-death age

import pandas as pd

# ─── Ensure first_start exists ────────────────────────────────────────────────
if 'first_start' not in cohort.columns:
    first_enc = (
        encounters
        .groupby('PATIENT', as_index=False)['START']
        .min()
        .rename(columns={'PATIENT':'patient_id','START':'first_start'})
    )
    cohort = cohort.merge(first_enc, on='patient_id', how='left')

# ─── Strip tz and compute age at first encounter ──────────────────────────────
cohort['BIRTHDATE']   = pd.to_datetime(cohort['BIRTHDATE']).dt.tz_localize(None)
cohort['first_start'] = pd.to_datetime(cohort['first_start']).dt.tz_localize(None)
cohort['age_event']   = (cohort['first_start'] - cohort['BIRTHDATE']).dt.days / 365.25

# ─── Compute current/at-death age ─────────────────────────────────────────────
# Ensure DEATHDATE is datetime & tz-naive
cohort['DEATHDATE'] = pd.to_datetime(cohort['DEATHDATE']).dt.tz_localize(None)
# Define “today” or analysis cutoff
today = pd.Timestamp.today().normalize()
# Use DEATHDATE if present, otherwise today
end_date = cohort['DEATHDATE'].fillna(today)
cohort['age_current'] = (end_date - cohort['BIRTHDATE']).dt.days / 365.25

# ─── DEBUG: inspect the two age metrics before filtering ───────────────────────
print("Age at event summary:")
print(cohort['age_event'].describe(), "\n")
print("Current/at-death age summary:")
print(cohort['age_current'].describe(), "\n")
print("Sample age values:")
print(cohort[['patient_id','BIRTHDATE','first_start','age_event','DEATHDATE','age_current']].head(10), "\n")

# ─── Filter to adults (age ≥ 18 at first encounter) ──────────────────────────
cohort = cohort[cohort['age_event'] >= 18]
print(f"➤ Patients remaining after age_event ≥ 18 filter: {cohort.shape[0]}\n")
# Out:
# Age at event summary:
# count    15354.000000
# mean        13.304375
# std          6.321151
# min          0.000000
# 25%          9.559206
# 50%         17.133470
# 75%         18.149213
# max         19.167693
# Name: age_event, dtype: float64
#
# Current/at-death age summary:
# count    15354.000000
# mean        67.217791
# std         20.586787
# min          0.000000
# 25%         51.919233
# 50%         68.737851
# 75%         83.884326
# max        103.200548
# Name: age_current, dtype: float64
#
# Sample age values:
#                              patient_id  BIRTHDATE         first_start  \
# 0  0007b281-7eb0-f2b2-d12a-3fc1e2f7e3e2 1950-01-27 1968-03-22 15:35:11
# 1  0007efd3-c50d-7e51-6a30-8dc08d4269fc 1963-11-25 1981-06-23 06:45:29
# 2  000eba84-0d5c-2657-0b5e-0c70f2f746c2 1929-04-06 1929-10-11 04:41:09
# 3  000f23c8-470d-babb-5fda-2b13c6c54e80 1938-07-22 1956-09-14 13:01:28
# 4  0011c542-8a54-27c3-59d6-1575d265210e 1965-02-10 1966-07-09 01:53:25
# 5  001209d3-9cd3-a700-69ea-c9982213efea 1926-11-27 1945-01-20 23:59:41
# 6  0012d2ba-ece7-3907-1444-7dd7f5a6b445 1990-11-27 1999-10-02 00:22:38
# 7  0018051c-68a3-fd33-4549-ce131a4e974d 1965-10-15 1983-12-10 02:13:18
# 8  001b2c73-a0da-543d-512b-c48d62d39eae 1972-02-03 1990-03-29 11:48:28
# 9  001ebaa4-2659-e322-fedf-831d9d5dfb27 1939-01-20 1956-01-01 22:39:42
#
#    age_event  DEATHDATE  age_current
# 0  18.149213 2001-12-14    51.879535
# 1  17.577002        NaT    61.448323
# 2   0.514716        NaT    96.084873
# 3  18.149213        NaT    86.792608
# 4   1.407255        NaT    60.235455
# 5  18.149213 1992-10-22    65.902806
# 6   8.845996        NaT    34.442163
# 7  18.151951        NaT    59.559206
# 8  18.149213        NaT    53.256674
# 9  16.947296 2003-12-05    64.873374
#
# ➤ Patients remaining after age_event ≥ 18 filter: 7050

# %%
# Cell 9: Feature Engineering — Inpatient‐stay filter + debug
# DEBUG: show available encounter classes
print("Encounter classes available:", encounters['ENCOUNTERCLASS'].unique(), "\n")

# Filter to patients with at least one inpatient stay
mask_ip = (
    encounters['PATIENT'].isin(cohort['patient_id']) &
    (encounters['ENCOUNTERCLASS'].str.lower() == 'inpatient')
)
inpatient_patients = encounters.loc[mask_ip, 'PATIENT'].unique()
print(f"➤ Unique inpatient patient count: {len(inpatient_patients)}\n")

cohort = cohort[cohort['patient_id'].isin(inpatient_patients)]
print(f"➤ Patients remaining after inpatient-stay filter: {cohort.shape[0]}\n")
# Out:
# Encounter classes available: ['wellness' 'inpatient' 'ambulatory' 'outpatient' 'urgentcare' 'emergency'
#  'snf' 'hospice' 'home']
#
# ➤ Unique inpatient patient count: 2631
#
# ➤ Patients remaining after inpatient-stay filter: 2631

# %%
# Cell 10: Feature Engineering — Comorbidity Counts

# Count distinct condition codes per patient
comorbidity_counts = (
    conditions
    .groupby('PATIENT')['CODE']
    .nunique()
    .reset_index()
    .rename(columns={'PATIENT':'patient_id', 'CODE':'num_comorbidities'})
)

# Merge into cohort
cohort = cohort.merge(comorbidity_counts, on='patient_id', how='left')

print("Added num_comorbidities; sample:")
print(cohort[['patient_id','num_comorbidities']].head(), "\n")
# Out:
# Added num_comorbidities; sample:
#                              patient_id  num_comorbidities
# 0  005444f1-853d-ad2e-2ee6-b772b4bb8014                 24
# 1  007b9335-08e2-c478-a79a-d9d4b6e88f62                 16
# 2  009f3a51-db42-bb8d-daad-a03c46387522                 14
# 3  00ab49d7-9776-b5fd-abbd-5151ca805afb                 21
# 4  00b9b7eb-5bd2-718c-4966-2dabcc2a1528                 12

# %%
# Cell 11: Feature Engineering — One-hot encode Race & Ethnicity (deduplicated)

# 1) Drop any pre-existing race_/ethnicity_ columns to avoid duplicates
drop_cols = [c for c in cohort.columns if c.startswith('race_') or c.startswith('ethnicity_')]
cohort = cohort.drop(columns=drop_cols, errors='ignore')

# 2) Build one-hot dummies for RACE and ETHNICITY
race_ethn_dummies = pd.get_dummies(
    cohort[['RACE','ETHNICITY']],
    prefix=['race','ethnicity'],
    dummy_na=False
)

# 3) Attach patient_id for merging
race_ethn_dummies['patient_id'] = cohort['patient_id'].values

# 4) Merge the fresh dummies back into cohort
cohort = cohort.merge(race_ethn_dummies, on='patient_id', how='left')

# 5) Preview
print("Added race & ethnicity dummies; sample:")
print(cohort.filter(regex='^(race_|ethnicity_)').head(), "\n")
# Out:
# Added race & ethnicity dummies; sample:
#    race_asian  race_black  race_hawaiian  race_native  race_other  race_white  \
# 0       False       False          False        False       False        True
# 1       False       False          False        False       False        True
# 2       False       False          False        False       False        True
# 3       False       False          False        False       False        True
# 4       False       False          False        False       False        True
#
#    ethnicity_hispanic  ethnicity_nonhispanic
# 0               False                   True
# 1               False                   True
# 2               False                   True
# 3               False                   True
# 4               False                   True

# %%
# Cell 12 (edited): Feature Engineering — Pruned Observations Aggregation

# Path to observations file (from Cell 2)
obs_file = f"{base}\\observations.csv"

# Prepare mapping of patient → first_start
first_start_map = cohort.set_index('patient_id')['first_start'].to_dict()
patient_set     = set(first_start_map)

feature_chunks = []
reader = pd.read_csv(
    obs_file,
    usecols=['PATIENT','DATE','CODE','VALUE'],
    parse_dates=['DATE'],
    chunksize=10**6
)

for i, chunk0 in enumerate(reader, start=1):
    # 1) PATIENT filter (make an explicit copy)
    chunk1 = chunk0[chunk0['PATIENT'].isin(patient_set)].copy()
    if chunk1.empty:
        print(f"Chunk #{i}: total={len(chunk0)}, after PATIENT filter=0, after window filter=0")
        continue

    # 2) map first_start and drop tz on both columns
    chunk1.loc[:, 'first_start'] = (
        pd.to_datetime(chunk1['PATIENT'].map(first_start_map))
          .dt.tz_localize(None)
    )
    chunk1.loc[:, 'DATE'] = chunk1['DATE'].dt.tz_localize(None)

    # 3) time‐window filter [first_start, first_start + 48h]
    window = chunk1['first_start'] + pd.Timedelta(hours=48)
    mask   = (chunk1['DATE'] >= chunk1['first_start']) & (chunk1['DATE'] <= window)
    chunk2 = chunk1.loc[mask]

    # Debug print
    print(f"Chunk #{i}: total={len(chunk0)}, "
          f"after PATIENT filter={len(chunk1)}, "
          f"after window filter={len(chunk2)}")

    if chunk2.empty:
        continue

    # 4) coerce VALUE to numeric & drop non‐numeric
    chunk2.loc[:, 'VALUE'] = pd.to_numeric(chunk2['VALUE'], errors='coerce')
    chunk2 = chunk2.dropna(subset=['VALUE'])
    if chunk2.empty:
        continue

    # 5) pivot to get mean/min/max per CODE
    pt = chunk2.pivot_table(
        index='PATIENT',
        columns='CODE',
        values='VALUE',
        aggfunc=['mean','min','max']
    )
    pt.columns = [f"{stat}_{code}" for stat, code in pt.columns]
    pt = pt.reset_index().rename(columns={'PATIENT':'patient_id'})
    feature_chunks.append(pt)

# 6) concatenate & reduce
if feature_chunks:
    obs_concat   = pd.concat(feature_chunks, ignore_index=True)
    obs_features = obs_concat.groupby('patient_id', as_index=False).max()
else:
    obs_features = pd.DataFrame(columns=['patient_id'])

# 7) drop any old obs cols before merge
obs_cols = [c for c in cohort.columns if c.startswith(('mean_','min_','max_'))]
cohort  = cohort.drop(columns=obs_cols, errors='ignore')

# 8) merge in the fresh ones
cohort = cohort.merge(obs_features, on='patient_id', how='left')

print("Merged observation-based features; sample:")
print(cohort.filter(regex='^(mean|min|max)_').head(), "\n")
# Out:
# C:\Users\yanis\AppData\Local\Temp\ipykernel_16168\1986653746.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<DatetimeArray>
# ['2000-04-10 19:56:11', '2000-04-10 19:56:11', '2000-04-10 19:56:11',
#  '2000-04-10 19:56:11', '2000-04-10 19:56:11', '2000-04-10 19:56:11',
#  '2000-04-10 19:56:11', '2000-04-10 19:56:11', '2000-04-10 19:56:11',
#  '2000-04-10 19:56:11',
#  ...
#  '2013-11-04 06:29:28', '2013-11-04 06:29:28', '2013-11-04 06:29:28',
#  '2013-11-18 15:44:02', '2012-01-28 15:44:02', '2013-01-28 15:44:02',
#  '2012-01-28 15:44:02', '2013-01-28 15:44:02', '2012-01-28 15:44:02',
#  '2013-01-28 15:44:02']
# Length: 248396, dtype: datetime64[ns]' has dtype incompatible with datetime64[ns, UTC], please explicitly cast to a compatible dtype first.
#   chunk1.loc[:, 'DATE'] = chunk1['DATE'].dt.tz_localize(None)
# Chunk #1: total=1000000, after PATIENT filter=248396, after window filter=0
# C:\Users\yanis\AppData\Local\Temp\ipykernel_16168\1986653746.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<DatetimeArray>
# ['2004-02-09 15:44:02', '2004-02-09 15:44:02', '2004-02-09 15:44:02',
#  '2004-02-09 15:44:02', '2004-02-09 15:44:02', '2004-02-09 15:44:02',
#  '2004-02-09 15:44:02', '2004-02-09 15:44:02', '2004-02-09 15:44:02',
#  '2004-02-09 15:44:02',
#  ...
#  '2012-09-05 06:12:50', '2013-09-05 06:12:50', '2014-09-05 06:12:50',
#  '2015-09-05 06:12:50', '2016-09-05 06:12:50', '2017-09-05 06:12:50',
#  '2018-09-05 06:12:50', '2019-09-05 06:12:50', '2020-09-05 06:12:50',
#  '2021-09-05 06:12:50']
# Length: 228278, dtype: datetime64[ns]' has dtype incompatible with datetime64[ns, UTC], please explicitly cast to a compatible dtype first.
#   chunk1.loc[:, 'DATE'] = chunk1['DATE'].dt.tz_localize(None)
# Chunk #2: total=1000000, after PATIENT filter=228278, after window filter=0
# C:\Users\yanis\AppData\Local\Temp\ipykernel_16168\1986653746.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<DatetimeArray>
# ['1999-09-03 04:12:58', '1999-09-03 04:12:58', '1999-09-03 04:12:58',
#  '1999-09-03 04:12:58', '1999-09-03 04:12:58', '1999-09-03 04:12:58',
#  '1999-09-03 04:12:58', '1999-09-03 04:12:58', '1999-09-03 04:12:58',
#  '1999-09-03 05:05:43',
#  ...
#  '2006-06-24 09:27:07', '2006-06-24 09:27:07', '2006-06-24 09:27:07',
#  '2006-06-24 09:27:07', '2006-06-24 09:27:07', '2006-06-24 09:27:07',
#  '2006-06-24 09:27:07', '2006-06-24 09:27:07', '2006-06-24 09:27:07',
#  '2007-02-11 05:17:07']
# Length: 202498, dtype: datetime64[ns]' has dtype incompatible with datetime64[ns, UTC], please explicitly cast to a compatible dtype first.
#   chunk1.loc[:, 'DATE'] = chunk1['DATE'].dt.tz_localize(None)
# Chunk #3: total=1000000, after PATIENT filter=202498, after window filter=33
# C:\Users\yanis\AppData\Local\Temp\ipykernel_16168\1986653746.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<DatetimeArray>
# ['1967-02-27 09:48:15', '1967-02-27 09:48:15', '1967-02-27 09:48:15',
#  '1967-02-27 09:48:15', '1967-02-27 09:48:15', '1967-02-27 09:48:15',
#  '1967-02-27 09:48:15', '1967-02-27 09:48:15', '1967-02-27 09:48:15',
#  '1967-02-27 10:22:33',
#  ...
#  '1987-01-12 10:38:05', '1987-01-12 10:38:05', '1987-01-12 10:38:05',
#  '1987-01-12 10:38:05', '1987-01-12 10:38:05', '1987-01-12 10:38:05',
#  '1987-01-12 10:38:05', '1987-01-12 10:57:56', '1987-01-12 11:40:24',
#  '1988-01-25 09:45:42']
# Length: 204574, dtype: datetime64[ns]' has dtype incompatible with datetime64[ns, UTC], please explicitly cast to a compatible dtype first.
#   chunk1.loc[:, 'DATE'] = chunk1['DATE'].dt.tz_localize(None)
# Chunk #4: total=1000000, after PATIENT filter=204574, after window filter=0
# C:\Users\yanis\AppData\Local\Temp\ipykernel_16168\1986653746.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<DatetimeArray>
# ['1979-07-26 00:03:55', '1979-07-26 00:03:55', '1979-07-26 00:03:55',
#  '1979-07-26 00:03:55', '1979-07-26 00:03:55', '1979-07-26 00:03:55',
#  '1979-07-26 00:03:55', '1979-07-26 00:03:55', '1979-07-26 00:03:55',
#  '1979-07-26 00:03:55',
#  ...
#  '1989-11-11 18:04:43', '1989-11-11 18:04:43', '1989-11-11 18:04:43',
#  '1989-11-11 18:04:43', '1989-11-11 18:04:43', '1989-11-11 18:04:43',
#  '1989-11-11 18:04:43', '1989-11-11 18:04:43', '1989-11-11 18:04:43',
#  '1990-05-26 17:17:45']
# Length: 220180, dtype: datetime64[ns]' has dtype incompatible with datetime64[ns, UTC], please explicitly cast to a compatible dtype first.
#   chunk1.loc[:, 'DATE'] = chunk1['DATE'].dt.tz_localize(None)
# Chunk #5: total=1000000, after PATIENT filter=220180, after window filter=34
# C:\Users\yanis\AppData\Local\Temp\ipykernel_16168\1986653746.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<DatetimeArray>
# ['2011-01-09 14:13:18', '2011-01-09 14:13:18', '2011-01-09 14:13:18',
#  '2011-01-09 14:13:18', '2011-01-09 14:13:18', '2011-01-09 14:13:18',
#  '2011-01-09 14:13:18', '2011-01-09 14:13:18', '2011-01-09 14:13:18',
#  '2011-01-09 14:13:18',
#  ...
#  '2020-11-10 02:46:00', '2021-11-10 02:46:00', '2012-07-15 22:41:45',
#  '2013-08-15 13:41:45', '2013-08-15 13:41:45', '2013-08-15 13:41:45',
#  '2013-08-15 13:41:45', '2013-08-15 13:41:45', '2013-08-15 13:41:45',
#  '2013-08-15 13:41:45']
# Length: 216102, dtype: datetime64[ns]' has dtype incompatible with datetime64[ns, UTC], please explicitly cast to a compatible dtype first.
#   chunk1.loc[:, 'DATE'] = chunk1['DATE'].dt.tz_localize(None)
# Chunk #6: total=1000000, after PATIENT filter=216102, after window filter=0
# C:\Users\yanis\AppData\Local\Temp\ipykernel_16168\1986653746.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<DatetimeArray>
# ['2013-08-15 13:41:45', '2013-08-15 13:41:45', '2013-08-15 14:18:23',
#  '2013-08-15 14:18:23', '2013-08-15 14:18:23', '2013-08-15 14:18:23',
#  '2013-08-15 14:18:23', '2013-08-15 14:18:23', '2013-08-15 14:18:23',
#  '2013-08-15 14:18:23',
#  ...
#  '2009-01-23 11:45:42', '2009-01-26 00:32:02', '2009-01-26 00:32:02',
#  '2009-01-27 00:32:02', '2009-01-27 00:32:02', '2009-01-31 00:32:02',
#  '2009-01-31 00:32:02', '2009-02-01 00:32:02', '2009-02-01 00:32:02',
#  '2009-02-08 23:14:44']
# Length: 218920, dtype: datetime64[ns]' has dtype incompatible with datetime64[ns, UTC], please explicitly cast to a compatible dtype first.
#   chunk1.loc[:, 'DATE'] = chunk1['DATE'].dt.tz_localize(None)
# Chunk #7: total=1000000, after PATIENT filter=218920, after window filter=0
# C:\Users\yanis\AppData\Local\Temp\ipykernel_16168\1986653746.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<DatetimeArray>
# ['1963-08-19 15:04:33', '1963-08-19 15:04:33', '1963-08-19 15:04:33',
#  '1963-08-19 15:04:33', '1963-08-19 15:04:33', '1963-08-19 15:04:33',
#  '1963-08-19 15:04:33', '1963-08-19 15:04:33', '1963-08-19 15:04:33',
#  '1963-08-19 15:58:07',
#  ...
#  '2014-03-23 14:35:41', '2015-03-23 14:35:41', '2016-03-23 14:35:41',
#  '2017-03-23 14:35:41', '2012-03-23 14:35:41', '2013-03-23 14:35:41',
#  '2014-03-23 14:35:41', '2015-03-23 14:35:41', '2016-03-23 14:35:41',
#  '2017-03-23 14:35:41']
# Length: 226070, dtype: datetime64[ns]' has dtype incompatible with datetime64[ns, UTC], please explicitly cast to a compatible dtype first.
#   chunk1.loc[:, 'DATE'] = chunk1['DATE'].dt.tz_localize(None)
# Chunk #8: total=1000000, after PATIENT filter=226070, after window filter=0
# C:\Users\yanis\AppData\Local\Temp\ipykernel_16168\1986653746.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<DatetimeArray>
# ['2010-06-13 10:07:16', '2010-06-13 10:07:16', '2010-06-13 10:07:16',
#  '2010-06-13 10:07:16', '2010-06-13 10:07:16', '2010-06-13 10:07:16',
#  '2010-06-13 10:07:16', '2010-06-13 10:07:16', '2010-06-13 10:07:16',
#  '2010-06-13 10:07:16',
#  ...
#  '1972-05-13 12:19:03', '1972-05-13 12:19:03', '1972-05-13 12:19:03',
#  '1972-05-13 12:19:03', '1972-05-13 12:19:03', '1972-05-13 12:19:03',
#  '1972-05-13 12:19:03', '1972-05-13 12:19:03', '1972-05-13 12:19:03',
#  '1972-05-13 12:19:03']
# Length: 230529, dtype: datetime64[ns]' has dtype incompatible with datetime64[ns, UTC], please explicitly cast to a compatible dtype first.
#   chunk1.loc[:, 'DATE'] = chunk1['DATE'].dt.tz_localize(None)
# Chunk #9: total=1000000, after PATIENT filter=230529, after window filter=0
# C:\Users\yanis\AppData\Local\Temp\ipykernel_16168\1986653746.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<DatetimeArray>
# ['1972-05-13 12:19:03', '1972-05-13 13:00:18', '1972-05-13 13:00:18',
#  '1972-05-13 13:00:18', '1972-05-13 13:00:18', '1972-05-13 13:00:18',
#  '1972-05-13 13:00:18', '1972-05-13 13:00:18', '1972-05-13 13:00:18',
#  '1972-05-13 13:00:18',
#  ...
#  '1989-10-07 02:07:41', '1989-10-07 02:07:41', '1989-10-07 02:07:41',
#  '1989-10-07 02:26:55', '1989-10-07 02:56:47', '1989-10-07 02:56:47',
#  '1989-10-07 03:39:38', '1989-10-07 04:17:53', '1989-10-07 04:56:31',
#  '1989-11-25 01:09:19']
# Length: 196199, dtype: datetime64[ns]' has dtype incompatible with datetime64[ns, UTC], please explicitly cast to a compatible dtype first.
#   chunk1.loc[:, 'DATE'] = chunk1['DATE'].dt.tz_localize(None)
# Chunk #10: total=1000000, after PATIENT filter=196199, after window filter=0
# C:\Users\yanis\AppData\Local\Temp\ipykernel_16168\1986653746.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<DatetimeArray>
# ['2002-05-29 06:23:06', '2002-05-29 06:23:06', '2002-05-29 06:23:06',
#  '2002-05-29 06:23:06', '2002-05-29 06:23:06', '2002-05-29 06:23:06',
#  '2002-05-29 06:23:06', '2002-05-29 06:23:06', '2002-05-29 06:23:06',
#  '2002-05-29 06:23:06',
#  ...
#  '1991-03-08 08:56:17', '1991-03-08 08:56:17', '1991-03-08 08:56:17',
#  '1991-03-08 08:56:17', '1991-03-10 06:12:17', '1991-03-10 06:12:17',
#  '1991-03-10 06:12:17', '1991-03-10 06:12:17', '1991-03-10 06:12:17',
#  '1991-04-19 07:44:29']
# Length: 228450, dtype: datetime64[ns]' has dtype incompatible with datetime64[ns, UTC], please explicitly cast to a compatible dtype first.
#   chunk1.loc[:, 'DATE'] = chunk1['DATE'].dt.tz_localize(None)
# Chunk #11: total=1000000, after PATIENT filter=228450, after window filter=0
# Chunk #12: total=161255, after PATIENT filter=34358, after window filter=0
# Merged observation-based features; sample:
#   mean_29463-7 mean_39156-5 mean_59576-9 mean_63512-8 mean_63586-2  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   mean_70274-6 mean_72514-3 mean_75626-2 mean_8302-2 mean_8462-4  ...  \
# 0          NaN          NaN          NaN         NaN         NaN  ...
# 1          NaN          NaN          NaN         NaN         NaN  ...
# 2          NaN          NaN          NaN         NaN         NaN  ...
# 3          NaN          NaN          NaN         NaN         NaN  ...
# 4          NaN          NaN          NaN         NaN         NaN  ...
#
#   max_72514-3 max_75626-2 max_8302-2 max_8462-4 max_8480-6 max_8867-4  \
# 0         NaN         NaN        NaN        NaN        NaN        NaN
# 1         NaN         NaN        NaN        NaN        NaN        NaN
# 2         NaN         NaN        NaN        NaN        NaN        NaN
# 3         NaN         NaN        NaN        NaN        NaN        NaN
# 4         NaN         NaN        NaN        NaN        NaN        NaN
#
#   max_9279-1 mean_55758-7 min_55758-7 max_55758-7
# 0        NaN          NaN         NaN         NaN
# 1        NaN          NaN         NaN         NaN
# 2        NaN          NaN         NaN         NaN
# 3        NaN          NaN         NaN         NaN
# 4        NaN          NaN         NaN         NaN
#
# [5 rows x 42 columns]
# C:\Users\yanis\AppData\Local\Temp\ipykernel_16168\1986653746.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<DatetimeArray>
# ['2012-04-06 03:02:42', '2012-04-06 03:02:42', '2012-04-06 03:02:42',
#  '2012-04-06 03:02:42', '2012-04-06 03:02:42', '2012-04-06 03:02:42',
#  '2012-04-06 03:02:42', '2012-04-06 03:02:42', '2012-04-06 03:02:42',
#  '2012-04-06 03:02:42',
#  ...
#  '2013-01-26 07:22:22', '2014-01-26 07:22:22', '2015-01-26 07:22:22',
#  '2016-01-26 07:22:22', '2017-01-26 07:22:22', '2018-01-26 07:22:22',
#  '2019-01-26 07:22:22', '2020-01-26 07:22:22', '2021-01-26 07:22:22',
#  '2022-01-26 07:22:22']
# Length: 34358, dtype: datetime64[ns]' has dtype incompatible with datetime64[ns, UTC], please explicitly cast to a compatible dtype first.
#   chunk1.loc[:, 'DATE'] = chunk1['DATE'].dt.tz_localize(None)

# %%
# Cell 13: Save the fully‑enriched cohort

output_path = 'cohort_enriched.csv'
cohort.to_csv(output_path, index=False)
print(f"Enriched cohort saved to {output_path}")
# Out:
# Enriched cohort saved to cohort_enriched.csv

# %%
### Preprocessing

# %%
# ─── Drop unused observation features ───────────────────────────────────────
drop_empty = ['mean_55758-7', 'min_55758-7', 'max_55758-7']
cohort = cohort.drop(columns=drop_empty, errors='ignore')
print("Dropped empty features:", drop_empty)
# Out:
# Dropped empty features: ['mean_55758-7', 'min_55758-7', 'max_55758-7']

# %%
# Cell 14: Preprocessing Pipeline (fix for boolean dummies)

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, RobustScaler

# 1) Build numeric_feats: 
#    – age_event, age_current, num_comorbidities
#    – all obs-derived stats (mean_, min_, max_)
#    – AND any race_/ethnicity_ dummy columns (0/1)
numeric_feats = [
    'age_event', 'age_current', 'num_comorbidities'
] + [
    c for c in cohort.columns 
    if c.startswith(('mean_','min_','max_','race_','ethnicity_'))
]

# 2) Build categorical_feats, picking up either case
categorical_feats = [c for c in ['GENDER'] if c in cohort.columns]


print("Numeric features used:", numeric_feats)
print("Categorical features used:", categorical_feats)

# 3) Numeric pipeline: median impute + robust scaling
numeric_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler',  RobustScaler())
])

# 4) Categorical pipeline: constant impute + one-hot encode
categorical_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value='unknown')),
    ('onehot',  OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# 5) Assemble only the non-empty transformers
transformers = [
    ('num', numeric_transformer, numeric_feats)
]
if categorical_feats:
    transformers.append(
        ('cat', categorical_transformer, categorical_feats)
    )

preprocessor = ColumnTransformer(transformers=transformers)

# 6) Fit & transform
X = preprocessor.fit_transform(cohort)

print("Preprocessing complete.")
print(f"  • Preprocessed feature matrix shape: {X.shape}")
# Out:
# Numeric features used: ['age_event', 'age_current', 'num_comorbidities', 'race_asian', 'race_black', 'race_hawaiian', 'race_native', 'race_other', 'race_white', 'ethnicity_hispanic', 'ethnicity_nonhispanic', 'mean_29463-7', 'mean_39156-5', 'mean_59576-9', 'mean_63512-8', 'mean_63586-2', 'mean_70274-6', 'mean_72514-3', 'mean_75626-2', 'mean_8302-2', 'mean_8462-4', 'mean_8480-6', 'mean_8867-4', 'mean_9279-1', 'min_29463-7', 'min_39156-5', 'min_59576-9', 'min_63512-8', 'min_63586-2', 'min_70274-6', 'min_72514-3', 'min_75626-2', 'min_8302-2', 'min_8462-4', 'min_8480-6', 'min_8867-4', 'min_9279-1', 'max_29463-7', 'max_39156-5', 'max_59576-9', 'max_63512-8', 'max_63586-2', 'max_70274-6', 'max_72514-3', 'max_75626-2', 'max_8302-2', 'max_8462-4', 'max_8480-6', 'max_8867-4', 'max_9279-1']
# Categorical features used: ['GENDER']
# Preprocessing complete.
#   • Preprocessed feature matrix shape: (2631, 52)

# %%
# Cell 15: Inspect, Clean, and EDA on Cohort file

# 1) Load the enriched cohort
df = pd.read_csv('cohort_enriched.csv')

# 2) Show all rows (temporarily)
pd.set_option('display.max_rows', None)
display(df)
pd.reset_option('display.max_rows')

# 3) List all column names
print("Columns in df:", df.columns.tolist(), "\n")

# 4) Drop unwanted columns
cols_to_drop = [
    'SSN', 'DRIVERS', 'PASSPORT', 'PREFIX', 'SUFFIX', 'MARITAL',
    'BIRTHPLACE', 'ADDRESS', 'CITY', 'STATE', 'COUNTY', 'ZIP',
    'LAT', 'LON', 'HEALTHCARE_EXPENSES', 'HEALTHCARE_COVERAGE',
    'mean_55758‑7','min_55758‑7','max_55758‑7'
]
df = df.drop(columns=cols_to_drop, errors='ignore')
print(f"Dropped columns: {cols_to_drop}\n")

# 5) EDA: class balance
print("Lung_label counts:")
print(df['lung_label'].value_counts(), "\n")
print("Lung_label proportions:")
print(df['lung_label'].value_counts(normalize=True), "\n")

# 6) Numeric summaries
print("Numeric feature summary:")
print(df.describe(include='number').transpose(), "\n")

# 7) Categorical summaries for any remaining categorical cols
cat_cols = df.select_dtypes(include='object').columns.tolist()
print("Categorical feature counts:")
print(df[cat_cols].nunique().to_frame(name='unique_values'), "\n")
# Out:
#                                 patient_id  lung_label  first_lung_code  \
# 0     005444f1-853d-ad2e-2ee6-b772b4bb8014       False              NaN
# 1     007b9335-08e2-c478-a79a-d9d4b6e88f62       False              NaN
# 2     009f3a51-db42-bb8d-daad-a03c46387522       False              NaN
# 3     00ab49d7-9776-b5fd-abbd-5151ca805afb       False              NaN
# 4     00b9b7eb-5bd2-718c-4966-2dabcc2a1528       False              NaN
# 5     00ce3347-9eec-c6f3-c758-8facb009daa7       False              NaN
# 6     00da8d4d-eb67-fd28-3d9e-77c97175fd2b       False              NaN
# 7     00e84dc3-ce19-c87b-fa8f-b42e3d13869f       False              NaN
# 8     01274098-150f-8211-6150-29f2a2da266c        True      233604007.0
# 9     01296e88-f6d9-1c18-cf91-87523325e034       False              NaN
# 10    014dbdc3-d17d-5f62-27d3-1b506e2f86f7       False              NaN
# 11    015f88d8-942e-a346-e86a-9f450036e8b0       False              NaN
# 12    016342fe-2ad3-1083-ef5b-c7e99682751a       False              NaN
# 13    0167b67a-9945-c3ae-2c4c-c4ae74e47bcd       False              NaN
# 14    017e7165-eb02-ad1f-cecb-e661e5d38f49       False              NaN
# 15    018841b0-2350-9196-80a6-873c364eab4c       False              NaN
# 16    019f6fea-c96e-eb62-e9ad-f8e44349547b       False              NaN
# 17    01a57c90-08b9-b195-2ee1-87a2fa60bc5b       False              NaN
# 18    01b26000-5982-32e1-75b1-98de5f47f6a2       False              NaN
# 19    01b4decb-f0d4-76c6-41ed-9513e066acdb       False              NaN
# 20    01ca6bcc-e039-9f91-20f5-d55b447b9698       False              NaN
# 21    01cc40be-fe26-e2af-720a-80189c24bb52       False              NaN
# 22    01f575de-5bd4-665a-6f88-2b9ac9ffbb25       False              NaN
# 23    01f903f8-c99c-051e-3ab7-fc7f7115fa36        True      233604007.0
# 24    02177c81-7f46-8142-63f5-09bb506c9dc2       False              NaN
# 25    0226f105-2572-1c6f-15f0-1aa0438e40d0       False              NaN
# 26    02487efd-b796-1493-3746-82b583ae2af5       False              NaN
# 27    024dd727-6889-2725-9921-2d6d28753355       False              NaN
# 28    0258fac5-fafa-c6fe-7ecd-755aab6f3ffe        True      233604007.0
# 29    025d9feb-35cb-7b1b-ac22-2f556a2df8dd       False              NaN
# 30    0263f5db-4dde-6ea3-0dcc-d971bf98b704       False              NaN
# 31    02663e0b-2ec8-d904-2bc1-8a9d926828d9       False              NaN
# 32    02711812-08b2-0fe1-2ef1-6e85f9272ce2        True      233604007.0
# 33    0290708b-7ad7-dd4a-0efa-9e629e648aa2       False              NaN
# 34    0296ca4b-2562-91fe-ece2-36f9f8e56976       False              NaN
# 35    02997c2c-7319-f003-ed89-9358ac437a0b       False              NaN
# 36    02b80efd-efca-43aa-457c-9115da86f227       False              NaN
# 37    02be46c9-90f5-e6db-4c01-045acb227dd1       False              NaN
# 38    02bf79b2-bac0-be6c-2f9a-e8d268996462        True      233604007.0
# 39    02ea1ae3-7a42-9054-993e-3c40833ca078       False              NaN
# 40    03094bad-05c3-23e0-7554-5766aa0b5c71       False              NaN
# 41    0313bae7-fd99-f893-3c3b-1a468c31b283       False              NaN
# 42    0352c2aa-cb33-84d3-6d5a-3e534f63ebf2       False              NaN
# 43    0354645f-84ae-a2bf-aedc-521b1c570f60       False              NaN
# 44    03813559-e761-8d69-aee3-7ddff324379f       False              NaN
# 45    03c0662e-1e95-6445-3826-d502e8c5ccfb       False              NaN
# 46    03cb1bcf-8960-8090-5ed8-4e2538e48327       False              NaN
# 47    03ec84a6-eb14-bd09-cb3a-795bd98742c3       False              NaN
# 48    0416eebf-7c5b-45d3-0b81-5092270f007e       False              NaN
# 49    0424aa46-9b57-40a1-4572-3280489ea2a4       False              NaN
# 50    0425b284-e697-937d-a00b-6fda0f1b9710       False              NaN
# 51    044156a0-5a78-3acf-436c-d9d3da13c60d       False              NaN
# 52    04439011-6a76-8606-1879-2a630330d1d1       False              NaN
# 53    0454158f-0daf-0bfb-642a-e0d836593183       False              NaN
# 54    0470d69b-2e17-b992-5011-bd96842832cf       False              NaN
# 55    0478885e-20be-8de0-c498-f34757f76e82       False              NaN
# 56    04882424-04bc-4031-09f5-423a832dbda9        True      233604007.0
# 57    04ab2fef-39a4-c27b-5b5e-e3f59a588d02       False              NaN
# 58    04b5b5d6-5496-1087-22db-453ae9241b2e        True      233604007.0
# 59    04da0d65-2987-32c5-a733-bccef3359aef       False              NaN
# 60    04fbd6d8-aaa9-df5e-648d-5e3e39857d8c        True      233604007.0
# 61    0502d9e5-69c0-b4c1-9c48-7b96db17a50e       False              NaN
# 62    0543076f-807d-b319-afe9-32a3c2608e2a       False              NaN
# 63    05ac3f51-1159-35ef-6c3c-8bba47cc27fc        True      233604007.0
# 64    05b68474-001e-66c3-8e42-4ca70d5b3c3c       False              NaN
# 65    05e6494e-fbb6-9400-0851-772e0941055c       False              NaN
# 66    05f5e3e4-b5e0-f4a1-64ae-011ec0206416       False              NaN
# 67    05f88be0-a422-2741-dc94-b38c2f683511        True      233604007.0
# 68    0606813a-3bd7-119d-063f-b5511f65bb0c        True      233604007.0
# 69    0633660a-b183-d358-9c68-05d54b440496        True      185086009.0
# 70    0653612e-1c01-3aa4-cc69-22fd4ca51ad7       False              NaN
# 71    066592d3-8788-415a-c9de-83b1379cf300       False              NaN
# 72    06922570-504b-5fd8-8b92-5ee19839e475       False              NaN
# 73    06922725-bc1c-5de8-cc4f-b2eb6ed74687       False              NaN
# 74    06a93a58-87dd-41da-2968-50d71804ae88       False              NaN
# 75    06d31a63-5182-0696-435d-7f83e163368b       False              NaN
# 76    06d47239-838a-a766-58f2-460c95f96fbe        True      233604007.0
# 77    06dece46-0661-4e8b-4fb1-de9d4d827654        True      233604007.0
# 78    07005671-ef5b-d1b9-d552-955c98cc6799       False              NaN
# 79    0706e7bd-bfd3-dad5-4335-732b8a32c56e        True      233604007.0
# 80    07328bf0-8c7e-10f6-a797-f38bff54f368       False              NaN
# 81    074ecd13-e999-309a-c62e-c25edd93a6b3       False              NaN
# 82    0763ad4d-494f-7206-2756-2660161eaf7e        True      233604007.0
# 83    077e1376-0eb7-a41d-def3-11b98681c713       False              NaN
# 84    0782eb8e-31aa-8c69-ca2b-cebaa6fc9b38       False              NaN
# 85    0790dcc4-103e-ee39-f9f7-b78c14ce990e       False              NaN
# 86    07c387ca-2e6b-f034-7adc-475612a2b706       False              NaN
# 87    0825bc4b-ab9a-f551-71f1-9e2d5006f902       False              NaN
# 88    0842e182-0723-d73d-d413-3714d52bb1eb       False              NaN
# 89    084e5bb4-5185-52f4-586b-26e744d7e11e       False              NaN
# 90    08642d7d-1640-e07a-21a6-b68f1c61ce42       False              NaN
# 91    086eafed-aa49-2313-133d-5c8fdd9052d0       False              NaN
# 92    0876a879-edee-6613-8a1f-13171657010c       False              NaN
# 93    08827760-2472-266c-fd03-351ac257b067       False              NaN
# 94    08a514f2-cd6d-2382-c2f5-acb258419efc       False              NaN
# 95    08aa508e-0b5a-0b3c-be1a-a939dcf912aa       False              NaN
# 96    08b37026-8469-e5d4-bc38-aa685fce7d23       False              NaN
# 97    08e846ff-a939-5621-0b6e-d6b7e0450b74        True      233604007.0
# 98    08ef7807-b3f3-58e4-1c67-3a64393a8b50       False              NaN
# 99    090375ca-02f8-6ae9-7829-8758297ec196       False              NaN
# 100   091ee656-36df-5cf4-9ea7-bd1abec8247e       False              NaN
# 101   09770e32-6cb5-4ee3-bc27-07ef0b3f9831       False              NaN
# 102   0979b7f1-a8d3-22fb-7940-716a4e400646       False              NaN
# 103   09818162-cca1-3d6d-ce52-a3bff2fc30a2       False              NaN
# 104   09821486-2d2a-8a14-17c8-7c6d78baee05       False              NaN
# 105   0996cfe2-5ec5-f267-4ba5-8e172f1bbd13       False              NaN
# 106   09ac67da-39e1-ab3b-c39f-aa9763e97a8c       False              NaN
# 107   09ad6c6a-f49c-c163-a9f6-33b0afcc58ff       False              NaN
# 108   09af65e3-86b4-5dc6-9643-ea95e3f5302b       False              NaN
# 109   09d0783c-2cbe-bbfb-8bfa-e720dbca63ef       False              NaN
# 110   0a040de5-1bc2-6303-7575-4a2df93e3c6f       False              NaN
# 111   0a1410ca-c37b-04e1-2c51-8d6b8604ee42       False              NaN
# 112   0a1a4b99-1a70-58bc-1efe-11fa0dfd93a6       False              NaN
# 113   0a20576e-51d6-91b1-779d-c6178ac46ec0       False              NaN
# 114   0a3aae93-0c5f-6cf4-538d-2bd3faea5465        True      233604007.0
# 115   0a76d7f3-ee11-4e66-0ab5-814abc27e292       False              NaN
# 116   0a8da05a-a518-8613-64dd-cbc98dca2206       False              NaN
# 117   0a90c520-5e04-b914-a302-8cc254b1be97        True      233604007.0
# 118   0abb8828-fd30-1bb0-5158-3cd540059810       False              NaN
# 119   0abc5db2-3126-56cf-509f-9ca36d5469ff       False              NaN
# 120   0b376215-5789-6dfd-d201-d4ba80db1791       False              NaN
# 121   0b4b624f-0c50-a019-03ca-841eaf9cab5e       False              NaN
# 122   0b725540-a32e-03b0-41f1-78e69bb095df       False              NaN
# 123   0b7c231f-2ca4-4fb1-d623-057c92aa66c9       False              NaN
# 124   0b9c1296-fe3f-e763-5f20-74d509c12bc4       False              NaN
# 125   0bb07a13-c9dc-9ee3-50cc-e61d40be567e       False              NaN
# 126   0be506a0-e758-27c8-db90-3132fd2b7761       False              NaN
# 127   0be707df-9f26-6834-1168-59f7a5f16085        True      233604007.0
# 128   0bf302e7-b152-b23c-3e70-6cae580bacc5       False              NaN
# 129   0c1bc806-22fc-d9dd-9835-afd55e22462e       False              NaN
# 130   0c2570ae-e175-258d-2bb3-70f8a3c1958a       False              NaN
# 131   0c37ae60-3d11-ec69-37a9-350e99b75905       False              NaN
# 132   0c395ccc-e302-1a7c-c57b-f93cbcda7e68       False              NaN
# 133   0c3a8fa5-7bff-a9fe-3e71-4d39728e2f66       False              NaN
# 134   0c6db575-20fe-5c77-1f8f-d1ffad7c40ef       False              NaN
# 135   0c84601a-5a84-0d08-97a3-9bb42d529c13        True      185086009.0
# 136   0cd04387-6636-d375-3ca9-3de069678218        True      233604007.0
# 137   0ce49233-2b01-ef26-e9d9-036950db4586       False              NaN
# 138   0d04ad38-372f-4496-d925-4fa9f5373c58       False              NaN
# 139   0d10c13a-85cb-1e60-bc79-9d7239dd075a       False              NaN
# 140   0d26453f-63b1-26ce-2df1-d8d41a3050d1       False              NaN
# 141   0d3ef68d-1d4a-fd51-632a-19164da916a3       False              NaN
# 142   0d3fc33b-29b2-d11b-7db4-99d5841819b8       False              NaN
# 143   0d4cd36a-8f94-936a-3211-0e21cc70be7f       False              NaN
# 144   0d5129c9-db89-cfb8-5dc5-1bbc79c3aa02       False              NaN
# 145   0d537ab8-f88b-e34b-e3e6-1612441ebdb7       False              NaN
# 146   0d8b884a-0512-da72-8cf4-c5aa8fd0454e       False              NaN
# 147   0db3f301-0c68-fa9c-847b-b64acb738674       False              NaN
# 148   0db84ca8-fd43-2fcc-efbe-0c854355cfb7       False              NaN
# 149   0de2ec3e-78d3-26d8-9268-7e48d18719d3       False              NaN
# 150   0defe917-b3e7-5bbe-8a48-6aa6e5222ff7       False              NaN
# 151   0e44b4f1-a0dd-2b35-afe4-fcdc7ecb2f3e       False              NaN
# 152   0e82eebf-2e10-1509-625a-c4d97725ab5e       False              NaN
# 153   0ec939a0-559c-7bc9-db9c-a7feae58634a       False              NaN
# 154   0ef4feee-3436-c2be-6d05-2c0dc44b8dac       False              NaN
# 155   0f28cf98-f010-3194-e1e6-0fa6e0f1308d       False              NaN
# 156   0f4697e1-3f10-b1c1-a80f-f88390e70bec       False              NaN
# 157   0f789413-8ad9-c82c-1722-a73c008166a9       False              NaN
# 158   0fd03daf-b2f5-3a06-3368-e9e82206989c       False              NaN
# 159   0fd3c446-4569-9833-c951-0c92c199f07b       False              NaN
# 160   1016e10d-2a87-10d1-8a2d-b3b5ff085d12       False              NaN
# 161   101826d0-79a5-037d-52a9-4dfa781a253c       False              NaN
# 162   103e0613-8219-35f2-695f-d35b4377b530       False              NaN
# 163   103f82f5-0b22-f117-44aa-f249edeee624       False              NaN
# 164   10446dde-501b-fa1d-1af8-ab9e1edede97       False              NaN
# 165   105866d3-6c9d-5a88-e18e-f0b1d3999ad7        True      233604007.0
# 166   106133e2-51af-edbc-b054-a371d0b97e84       False              NaN
# 167   10709244-d595-0101-2150-4fc0239c1464       False              NaN
# 168   1088f623-8911-1d3b-6cf7-5037b2acb885       False              NaN
# 169   10ab8952-ce68-75ed-79ed-9294689c42b9       False              NaN
# 170   10aea3f0-5271-98be-4800-3fde8fc5ec12        True      233604007.0
# 171   10e903c3-4be6-f9fe-0de9-661f2c0d1b46       False              NaN
# 172   10e98eff-75cf-612a-eb3e-045ca1a0d217       False              NaN
# 173   111ae885-b23d-daa5-0ab2-8e8eaad44e40       False              NaN
# 174   113703fe-eafd-6b4c-c5c4-973dc4a230a2        True      233604007.0
# 175   113e281b-47ce-14f6-2d94-d09fef7f89f7       False              NaN
# 176   114a0ae8-ae5f-b79a-221a-024d3edeb4bd       False              NaN
# 177   114deb62-1379-d991-f89d-5d73f4d5ddee        True      233604007.0
# 178   1156f91b-8cc2-94ec-fd8a-16f38570d4f7       False              NaN
# 179   1160578c-8397-7c6f-8dde-565976a5352e       False              NaN
# 180   117f1ac0-58f6-636b-4ee9-9f8f056596ca       False              NaN
# 181   11b6f950-da56-c1ea-2ae9-d5a8c9c96e10       False              NaN
# 182   11c282d4-6be2-2315-37be-323bf967425b       False              NaN
# 183   11c3df8f-ae15-8cf6-8625-324000afc38c       False              NaN
# 184   122f83bd-786f-cae7-8a66-bc1896e4f8d7       False              NaN
# 185   123123f1-51bf-a9b9-9bff-64e5c70d5a04        True      185086009.0
# 186   125fb4db-2e53-a77e-8ebc-9237d12356a2       False              NaN
# 187   12884475-5c77-a229-f56c-26cd15add63f        True      233604007.0
# 188   1297378d-1c3b-3417-6a93-a46b41420355       False              NaN
# 189   129b9b99-f534-35ee-f20b-4af5e4573a18        True      233604007.0
# 190   12afbd4e-7c24-9f1a-4d20-e6ac59d3853c       False              NaN
# 191   12b4a24c-b3e7-6029-6007-ab934ee23406       False              NaN
# 192   12d20d22-57d9-7ce0-0d72-b9014ab48f43       False              NaN
# 193   12f0d3df-7ea9-3005-ea7e-a4c829536a12        True      233604007.0
# 194   12f4633c-9a71-3184-1c72-1365af9b69d8        True      233604007.0
# 195   13148b6e-0c09-f1aa-f869-af36fc8f9cbf       False              NaN
# 196   131646b7-6562-427d-7f88-a77c1587cf93       False              NaN
# 197   133475ef-c579-bda3-ea95-d6d46330a5d6       False              NaN
# 198   13446c31-ca8d-2f48-82c4-139a8232cdf0        True      233604007.0
# 199   1366a220-8c5e-11f4-fc27-0e8c96d4011f       False              NaN
# 200   1397e516-c3de-5390-cb8d-b23b74b6cf5a        True      185086009.0
# 201   13b52524-4a2d-ff8d-0ecc-772a4caf0f23       False              NaN
# 202   13dd3862-a3df-5e2e-8545-d9b76a49c77d       False              NaN
# 203   13fb320f-5cc9-e1f4-f1d7-6bd88f56831e       False              NaN
# 204   142e05c4-758b-d11e-faa9-f861a4ae76a7       False              NaN
# 205   144450ef-7700-069b-6209-53ddbbad1bd4        True      233604007.0
# 206   144cf09d-b003-0802-c313-8f131f66eefc        True      185086009.0
# 207   145c541f-33d4-95f0-6228-722027a607d6       False              NaN
# 208   14a8eeaa-6d74-c569-db5b-0c29ad7c2532       False              NaN
# 209   14e57ea9-fbee-0841-0642-a449adabbec6       False              NaN
# 210   14f00e33-1107-e695-f65d-a4537ceb0957        True      233604007.0
# 211   14fc4c60-1be1-9a4b-644f-c24ae1a9d529        True      233604007.0
# 212   156cb567-f577-d860-d328-d160481e2305       False              NaN
# 213   15765897-a7ef-17b4-cac7-3c7266068592       False              NaN
# 214   158e697a-9560-d14b-9d0c-2972fb755037       False              NaN
# 215   15a480ef-7c52-167a-a10b-7a9b8dad95f7       False              NaN
# 216   15a87db9-aa01-fffd-3379-4e0aa05d6502       False              NaN
# 217   15bbdc61-ea4c-98ff-8e9f-b2a36853cbc9       False              NaN
# 218   161dc529-e52d-d895-509e-070d1dec4f19       False              NaN
# 219   16402d9a-3f6d-5962-8379-871e9873f25b       False              NaN
# 220   16959e12-c893-6f53-4789-9f071d498190       False              NaN
# 221   16a0aaf2-d719-d403-6c0d-9a23193cbdd0       False              NaN
# 222   16ae4738-c116-aaf3-4821-395067cc10d2       False              NaN
# 223   16c2c42d-722c-f279-ad38-5739566fd919       False              NaN
# 224   16cd2317-53bb-8610-366f-9ec392fc7bc2       False              NaN
# 225   16e35420-128e-b9dc-ced6-8c36e06cb698       False              NaN
# 226   16f71c69-e32e-e0fe-1a94-08dbb7331261       False              NaN
# 227   17171e7a-4f3e-6d97-cc8d-bbcede20f9a7       False              NaN
# 228   175b6e36-160d-b731-97df-e1b553aa200b       False              NaN
# 229   1766d2f8-7935-2462-9aaf-5131eb0aaf27       False              NaN
# 230   17697493-2726-81d3-46f9-2fca9b119cdf        True      233604007.0
# 231   177157d9-b760-1aff-23f0-f3c743312799       False              NaN
# 232   17ca3a5b-1de2-7884-fdfb-92b686dabcbf       False              NaN
# 233   17cc102b-d785-ea32-4ca2-27248782a07c       False              NaN
# 234   17d558ba-6eb9-e7b7-1ca7-b301542b5c63       False              NaN
# 235   17de8b4a-162c-79a2-1923-0f2f9281d857       False              NaN
# 236   17fc5228-ff40-0fe8-9cbc-a0ddd5443f44       False              NaN
# 237   181069b1-920f-5c78-2f6a-5a0386adddb8       False              NaN
# 238   18478c6b-675b-a6c5-20a5-b1e8b8c5b1ed       False              NaN
# 239   184e6358-ecbd-9401-4706-f9c23c0f92a8        True      233604007.0
# 240   185a7a8a-2849-033d-447a-2cac4071a40a       False              NaN
# 241   18786b24-6a29-4c58-8a62-fbf6fafdab9c       False              NaN
# 242   187dd60c-abb1-c51d-c8b4-f86c06d4e34d       False              NaN
# 243   188341ab-897f-ab4e-c026-683879fab957       False              NaN
# 244   1897b961-9fe4-a6e6-f320-f33d1a7d94fe       False              NaN
# 245   18b5b9d0-bf94-e97c-fe69-946eea318db5       False              NaN
# 246   18c3ea71-95ac-7b34-2f56-542fedc4e03c       False              NaN
# 247   18c967d8-4d56-57f5-2c45-676e5925db02       False              NaN
# 248   18eabcdd-9a79-9332-4734-30edf4045d86       False              NaN
# 249   18ef9749-7171-8f3f-16d6-3b7f9fb11cbd       False              NaN
# 250   190342f2-027f-dcf8-0139-19f45ef3aadd        True      233604007.0
# 251   190ae7b9-d75c-3263-fc64-ce9567fca07b        True      233604007.0
# 252   19190a6b-6345-01ae-09fe-0ff7fac6d601       False              NaN
# 253   193723fc-c714-3d90-2a98-de96dde50cf5       False              NaN
# 254   193931d5-6202-6e40-a158-3e7584ded96c        True      233604007.0
# 255   19579257-cd0c-8c8c-2a42-fe755ee152fb       False              NaN
# 256   19861abe-3c63-de14-f197-542c587287ec       False              NaN
# 257   198a8b71-a373-04ab-2a75-cfcfd57dd972       False              NaN
# 258   19bdccb1-dd97-5bbb-8569-0f005f1fa228       False              NaN
# 259   19dfa1e1-3d4f-a67e-a66f-56b3181f077d        True      185086009.0
# 260   19e57548-077a-e389-eaf3-ea3a04af91d8        True      233604007.0
# 261   19f2ef5d-297c-4deb-156f-b50d96a82039       False              NaN
# 262   1a0fdb24-a764-98bc-a4e3-a535abb79431       False              NaN
# 263   1a4eb9ed-5c56-81f6-6471-4b0523e8eed5       False              NaN
# 264   1a5ff605-8a61-d0df-be5a-042c7c550da7        True      233604007.0
# 265   1a65b170-6a95-77da-ec86-bf1c57d8a61c       False              NaN
# 266   1a8b3431-7c1d-4311-06d3-e54b91b770a4        True      185086009.0
# 267   1a8e33c9-ddd2-9e70-c795-af8b36fdc550       False              NaN
# 268   1b1c8491-fcd0-93f0-d73e-ab2d0f95714b       False              NaN
# 269   1b62a2cf-3d86-3e99-0773-f92b828427b6       False              NaN
# 270   1b7ab185-1497-f2d3-8a82-2c54a68defb2        True      233604007.0
# 271   1b83ebfd-bed4-9885-7b96-81dda371c5e3       False              NaN
# 272   1bb11c8a-fbc7-ece4-c134-042b7c54fec9       False              NaN
# 273   1bcd6fdb-e746-1a39-379c-9b67e534d468       False              NaN
# 274   1bd6c4e8-0150-04c5-01cb-a8ce9adf3dbf        True      185086009.0
# 275   1bfa0aeb-7c58-bcc5-3c91-71aebfd60514       False              NaN
# 276   1c01e970-4d42-cc0a-8c95-bd0759761df2       False              NaN
# 277   1c108ed8-584c-711e-723a-37239da0981b       False              NaN
# 278   1c164c6f-f915-35b7-2dcb-24598ec1f16c       False              NaN
# 279   1c1f673a-5e3c-4b39-97c6-3b8b66b93822       False              NaN
# 280   1c2d71bf-a9b3-25bb-7c59-6dc99fa13ad7        True      233604007.0
# 281   1c509b8e-2f21-2d07-6cf1-ae73f210a1d2       False              NaN
# 282   1c9e2c10-f232-4584-09ad-108775a6831c       False              NaN
# 283   1caf9adf-fa86-2b52-5694-28cb455cd755       False              NaN
# 284   1cdfd642-24b7-e8a6-86a5-8987ebe1da8e        True      233604007.0
# 285   1ce97ebe-a99c-0176-70a1-c70f01e3b6cf       False              NaN
# 286   1d09520c-407b-c9b6-67b1-66013f823ef0       False              NaN
# 287   1d106545-72aa-0bbb-c733-d26a2df3da14       False              NaN
# 288   1d1990f2-1efb-0bee-c14f-e160f8523abf        True      233604007.0
# 289   1d551426-29d8-8c24-e383-7c771d2e87bf       False              NaN
# 290   1d56f955-b749-7d3b-96da-b3111e2da9c5        True      233604007.0
# 291   1d8f77c0-029f-a024-5128-b317a42c6f3b       False              NaN
# 292   1da432d5-30a4-6c4d-d1d6-6219af415961       False              NaN
# 293   1dce547f-b35e-74ea-73d0-c9fb8df50cbd       False              NaN
# 294   1dda78f1-b9bf-8638-c546-612b63c95220       False              NaN
# 295   1ddbe73e-ca31-d82a-0694-d616987d1616       False              NaN
# 296   1dee0a42-d47c-e6a1-8802-7e85e2e7759f       False              NaN
# 297   1e0d3158-25e1-0429-f4f8-fa1479db0e2d       False              NaN
# 298   1e0fcc96-ba62-0d19-cd97-e6c683d8a8de       False              NaN
# 299   1e192f7e-5057-e767-f661-f2e888f03d49       False              NaN
# 300   1e46855a-47eb-44ec-2968-807addde721e       False              NaN
# 301   1e5603af-7831-ce48-afef-72bd19aee276       False              NaN
# 302   1e60973a-5250-9d73-6362-5ac75bfe2b29       False              NaN
# 303   1e615723-f427-c316-e84a-c2a2e03128cf       False              NaN
# 304   1e69de15-d162-6df1-0556-917d814f45fc       False              NaN
# 305   1e83b425-aa17-92e9-110a-8290933cc0cc        True      233604007.0
# 306   1e932765-fd2b-1f53-5478-450fd3c54cc3       False              NaN
# 307   1e96f6b0-a891-4b3e-8132-dcbbb398f7a5       False              NaN
# 308   1ebafe0c-52c8-9acc-5f3e-eec3d3599ecc        True      233604007.0
# 309   1ebbb751-efd1-8c48-4cb6-56bf1b1ada20       False              NaN
# 310   1ed4864d-27c6-0205-9cb9-b8883686ab89        True      233604007.0
# 311   1ed559e9-29ad-2208-413a-508543754a3d       False              NaN
# 312   1edb348c-55be-0017-4608-d4fdf31f7c6c       False              NaN
# 313   1ee34244-abb9-1722-9960-6f7620a4332c       False              NaN
# 314   1eead6f1-f57f-9aa1-a53e-6337bfe1e74e       False              NaN
# 315   1efcab9e-3662-a19d-4b6e-cf666968e72f        True      233604007.0
# 316   1f44224e-22b3-e9b5-2757-38c4befd519d       False              NaN
# 317   1f52da6f-3efe-577d-cbc1-4d4546c967eb       False              NaN
# 318   1f601bc3-727b-c0bc-a420-8ae8f467910b       False              NaN
# 319   1f8598ca-dd7d-1faa-d085-cff43e34be62       False              NaN
# 320   1f982a4d-c162-88d5-415b-fc4cab367c1b        True      233604007.0
# 321   1fb2a5b5-eeaf-afda-81e2-2638e8d98e9d       False              NaN
# 322   1fb55bb5-aeee-e50b-ef93-05f581e0766a       False              NaN
# 323   1fca1466-d67d-ea6a-48c3-dfcb1a65f0ce       False              NaN
# 324   1fd5b8d5-d3fe-3309-7b4c-9440073dc9fd       False              NaN
# 325   1ff930f0-c5da-1421-9635-89f7a281bf6a        True      233604007.0
# 326   20213f4a-c96c-60a5-4f35-21c94bfe9b17       False              NaN
# 327   20250bcd-31cd-fa88-201a-a8841c28adab       False              NaN
# 328   203c0836-e665-096a-b6bf-79e16cb2b395       False              NaN
# 329   207c6b66-cbfc-1a51-2949-ca59ca9d4b50       False              NaN
# 330   2085e7fa-b321-847e-db97-a331ae0ddbe6       False              NaN
# 331   209ac38a-634b-4350-b27b-effc1aac7d24       False              NaN
# 332   20a8ec18-fac1-b5cb-8945-4c7b7115a89d       False              NaN
# 333   20d15320-ca67-f50f-64bc-eb79892e8abb       False              NaN
# 334   20d93580-1fed-48f2-8b1f-ed3d26d78f26       False              NaN
# 335   2102a757-d1f4-90e8-8379-f21bdc2ad87a       False              NaN
# 336   2111ce0a-7498-cce6-7da9-6f4d83ee5a6d       False              NaN
# 337   21441fdc-4a1c-853e-19d6-d677803e0146        True      233604007.0
# 338   214fc8dc-182e-6ae7-6c47-8b14d68cd1ed       False              NaN
# 339   2153a9c3-fcb2-360f-2bbf-d1b25e926715        True      233604007.0
# 340   216a95bf-42a0-2b91-a789-95a89c001cb7       False              NaN
# 341   216f43ea-f872-3574-5504-c9af81c685e0        True      233604007.0
# 342   2171cb87-f51e-46bd-3877-157f20dc87c0        True      233604007.0
# 343   21a95f20-2d0e-c96e-9c82-c4b3ab30b4ec       False              NaN
# 344   21e3e28d-a9c0-d314-7157-3e0b1242f0f6        True      233604007.0
# 345   22234794-4c7a-1bc2-62c9-828df30c41e4       False              NaN
# 346   224468dd-d5e2-3187-23dc-1bcf1fba6f6a       False              NaN
# 347   224e66ec-9ebd-663c-84b7-86d894ca79c5       False              NaN
# 348   226e72cc-aa14-bbe5-9643-5a5a25035b1c       False              NaN
# 349   227d5d14-5566-ed13-03d0-fc08ab523463       False              NaN
# 350   2280f5b3-d70d-243a-e7f9-3d099a878315       False              NaN
# 351   228b9db0-2ae8-d2f3-2b1a-50632e3196d3       False              NaN
# 352   22c98cc3-1c3d-4b02-504a-1d59b8ce424b       False              NaN
# 353   231fea1e-4ab1-757c-4166-eb7bfd780007       False              NaN
# 354   2385ebd7-05c7-226b-1d7b-cdb3e172b2e3       False              NaN
# 355   23bdf523-9b78-afa2-79ac-c5c791ec694b       False              NaN
# 356   23be647e-97e6-8fb9-755c-6b606fe29ea4       False              NaN
# 357   23ca1e47-72e3-ca33-893a-a47cbd72acb6       False              NaN
# 358   23e691cb-c4a6-3099-b6c5-ad26e9a76338       False              NaN
# 359   23ebb008-dd17-b633-1005-3d479e4be802       False              NaN
# 360   24127379-0bba-41c7-a34b-e6e4da852435       False              NaN
# 361   24151a27-7cdc-096e-557a-7468e6f34966        True      233604007.0
# 362   241ce4c5-7deb-0f1e-8448-2960813f051d       False              NaN
# 363   2421f761-429e-1eb7-2d63-adf1d460d75f       False              NaN
# 364   2427d6fb-fd32-f442-9fa1-550672be5ed4        True      233604007.0
# 365   2435185c-c580-4f7f-9eb2-2ea942d85683       False              NaN
# 366   24478875-1eef-12ac-3b01-b3c5916ccd03       False              NaN
# 367   24593afb-c688-dfc5-2a04-fd6d1b1b7845       False              NaN
# 368   247de32a-e164-e436-503c-243971072284       False              NaN
# 369   2486a8c5-836a-711e-cc69-cb2089d52288       False              NaN
# 370   2490db00-ab18-bf4c-ec2f-6acc3b0bf70d       False              NaN
# 371   2497378b-aa52-e79c-9fe7-780c90b0ca05       False              NaN
# 372   249b9a92-feaf-09f6-9c54-baef208217b4       False              NaN
# 373   24ac9f81-ac7c-096a-c605-92918da55fc4       False              NaN
# 374   24bced6d-1ac6-09e4-e0ac-0a15388f50c2       False              NaN
# 375   24e20404-6c12-edeb-8abb-0aff9ab48843       False              NaN
# 376   250809ea-46ed-6ce1-e387-8ba618e76729       False              NaN
# 377   2521f627-c17c-72fa-41b9-61d04d4f3553       False              NaN
# 378   2527dbd8-f208-00e3-baa8-d8a096727513        True      185086009.0
# 379   25352dd2-389d-31a6-ae68-c5a68b596c1f       False              NaN
# 380   2540df85-2d48-54fb-8f1a-c1ce4864406f       False              NaN
# 381   25528a48-61a4-7076-3a5b-93eb708a3083       False              NaN
# 382   25b05242-4757-78e6-de1d-469aacdb89a8       False              NaN
# 383   25b1fe15-2ebd-d048-0b41-48c1ae7a332a       False              NaN
# 384   25e63755-23d3-1533-ac0e-58c1888981f8       False              NaN
# 385   26063d09-0d2a-731c-9dcd-ada3947dce41       False              NaN
# 386   26162b6d-2683-8e2b-ac19-c51e9c3f0827       False              NaN
# 387   261930a7-19c0-5c5e-718a-78eed85f2d7c       False              NaN
# 388   265b20d7-7db7-9966-daa9-99aa23fb87c9       False              NaN
# 389   26994a3c-dddf-3b67-1d60-adda2b93a7ba       False              NaN
# 390   26d9bbc8-527c-e5e9-5c38-404335ea1760        True      233604007.0
# 391   27593c28-139c-c1a6-31c1-4c3de4c06642       False              NaN
# 392   275dba8f-bb5a-a252-fe1e-40ccb3596163       False              NaN
# 393   2769aef7-575e-c592-353c-c3aa30d69c16       False              NaN
# 394   276d4a73-9736-b298-2300-8227333acd0d       False              NaN
# 395   276f9609-a3cf-1214-36a4-4a7a9da11531       False              NaN
# 396   2775b687-166e-37c4-6eb9-e2cf50cbe783       False              NaN
# 397   27f784e9-d427-1fa6-9037-bbf5eee0bc26       False              NaN
# 398   2814f3d1-7e63-8400-6c93-bcd140655d37        True      233604007.0
# 399   282a4ac1-17d1-c7b1-36d2-f49a4c50e1ed       False              NaN
# 400   2853ca5a-7862-68c8-07d1-3d7fa2d6ae27        True      233604007.0
# 401   285a9fea-0344-70a8-53f1-41d1e0a1df96       False              NaN
# 402   288c2d2c-41b9-f74a-970b-886a59b41842       False              NaN
# 403   28d6337e-b823-bcb4-fafb-c41adf1c78aa       False              NaN
# 404   28f4169d-32f0-d991-e565-b306c8ad5458       False              NaN
# 405   28f6dc94-d294-620b-397e-b0ca1807abe3       False              NaN
# 406   28f7ff07-9721-ce6c-4609-41e05ffd3b28        True      233604007.0
# 407   29104a02-b89f-0287-6b2a-3ebd8c4f4dcc        True      233604007.0
# 408   2913397d-de02-63ac-7ad5-b1efed292f06       False              NaN
# 409   294be94d-636b-1c5f-3b72-f43f1497813e        True      185086009.0
# 410   296aab90-e2b1-d991-820f-b6b9f5d0333f       False              NaN
# 411   296bb24c-45c9-0e8a-40e0-2b7e68463271       False              NaN
# 412   298f073b-98b3-5d5d-87e7-8fcc97a13799       False              NaN
# 413   2999ffe8-ab8a-3afa-ab9e-aa40fa162e8c        True      233604007.0
# 414   29ac4073-7869-51e5-d37b-03d6b9fa924f       False              NaN
# 415   29acea19-f714-c626-1096-3dd667963daf       False              NaN
# 416   29d00677-28cd-5919-359a-6c3225cb231e       False              NaN
# 417   29f7c2d0-4c50-8cf7-2b48-873cd7ff4410       False              NaN
# 418   2a193e8a-6d4a-df67-cf41-8e7541fbae33       False              NaN
# 419   2a5fa266-d96a-44d8-de75-d58bfc39d87f       False              NaN
# 420   2a8e2fe7-65b7-a574-b386-63a3eaf3a9d1       False              NaN
# 421   2a97f820-b412-041b-9d6a-7d44b0e172f6        True      233604007.0
# 422   2ac01dcb-d3e8-5f6e-529f-7069f9ae18d1       False              NaN
# 423   2acf0d30-1fa0-1669-32de-d72704fde11b       False              NaN
# 424   2adaad93-a3c3-2835-f74f-8198b64cffd0       False              NaN
# 425   2ae81439-1561-e9f5-8856-1c698d5d6a13       False              NaN
# 426   2af9dd1d-96c2-6b46-c40c-6548f942ed80       False              NaN
# 427   2b005d0d-a691-f620-9867-e53232e6e307       False              NaN
# 428   2b1c160d-d5f4-ece4-d76e-0f8b57733de3       False              NaN
# 429   2b1d1705-b6fe-56d8-a05e-44ec6fa3799d       False              NaN
# 430   2b21893e-436f-8b60-4802-e1e8f3cecfb7       False              NaN
# 431   2b485278-9216-40c6-0f3a-3ec3cc75d2ad       False              NaN
# 432   2b48af6a-3488-e8eb-4afa-002b445490aa       False              NaN
# 433   2b5ada6f-a63e-92bc-027e-22d2d654ff08       False              NaN
# 434   2b65ee28-1bae-0fe9-fb80-d8669c7011e8       False              NaN
# 435   2b842be7-685b-29c0-5600-fdb782b75b50       False              NaN
# 436   2ba833cd-0f48-02c7-71a7-070b31289436       False              NaN
# 437   2bb4fa22-c504-08fe-5055-c2a04b1c64c9       False              NaN
# 438   2bc0e8cb-e97f-7763-3383-1f6c78301d4d       False              NaN
# 439   2be1ce7d-a43b-7659-5ec5-6a28da40f990       False              NaN
# 440   2c12bd28-bf56-6094-bfc8-78b5513104e1        True      233604007.0
# 441   2c4ee40b-a9e3-176a-6192-4836810ae34e       False              NaN
# 442   2c7b19ce-e40c-4960-a5a8-26845dddc4e3       False              NaN
# 443   2c9bd38a-ccaf-a70f-2345-e31a0eefd27a        True      233604007.0
# 444   2ca3028c-9848-488e-03ee-ce3c2ce6563b       False              NaN
# 445   2cacc86d-a9c3-a47a-be18-dad821863eed        True      233604007.0
# 446   2cc45c94-ea1b-1317-bc1c-16e2a2640f92        True      233604007.0
# 447   2ce5c3c7-20c0-2957-2d87-e83acc3c237d       False              NaN
# 448   2d2e042d-ba5d-6480-c0b9-6e0356c8ccdf       False              NaN
# 449   2d30688c-f953-46b0-748b-5a8bc5a7bac2       False              NaN
# 450   2d30c101-aeb8-e893-86bb-72ff8af68650       False              NaN
# 451   2d505582-2c6c-181f-536c-8ffd8731bd12        True      233604007.0
# 452   2d840737-577b-6b8a-c24c-d8a15a0b4512       False              NaN
# 453   2d945e51-5338-c510-2825-c2d481e812ce        True      185086009.0
# 454   2d99eeb4-65c6-bade-dbce-d645cf18053f       False              NaN
# 455   2da7c4a5-4cab-59a4-a9a6-9720fddaff99        True      233604007.0
# 456   2dac99c3-2bf1-7f01-e0b7-3932b4d35dff       False              NaN
# 457   2df2d7ca-5b16-a5ab-51fa-fe26f73812ec       False              NaN
# 458   2e0a7fc1-4bbc-df24-aa83-c41e3c709284       False              NaN
# 459   2e25e9c1-0175-3e7f-0c4b-e7f9b7fb55de       False              NaN
# 460   2e2b2775-641b-c399-dc35-4f6fa90d80a0       False              NaN
# 461   2e2eaee8-54c6-ed2e-d729-8e88475daba5       False              NaN
# 462   2e3611d9-c5b2-164d-609d-2e4fc139cfd9        True      233604007.0
# 463   2e5386f0-85c7-6a17-ed77-d8fcecb78b9d        True      233604007.0
# 464   2e63952c-7f00-5aa9-f968-82cabbfde2ea       False              NaN
# 465   2ee4d22c-c42d-fea1-26c1-d5d64be0847b       False              NaN
# 466   2eeabc80-d86f-bef6-eb60-30abf7d3f1f8       False              NaN
# 467   2efc8e0b-32f8-a713-5cb8-1d15278b5e99       False              NaN
# 468   2f0428c1-0a43-97c4-db79-f093e2af56ed       False              NaN
# 469   2f0a1f1e-47b1-2890-81e1-0147f907cd82       False              NaN
# 470   2f342667-6225-b7d1-7b18-83203d6a33b4       False              NaN
# 471   2f39e90e-5f19-d42f-ecae-df9929ded7d9       False              NaN
# 472   2f3c5819-1119-6d82-7f77-4139d3485bae       False              NaN
# 473   2f5231cb-2f6b-1bf8-203c-09cd308fb983       False              NaN
# 474   2f64306c-c505-f324-1f87-aa55114a3fe6       False              NaN
# 475   2f6b17d6-73e7-e157-81c7-1a19ce3c4068       False              NaN
# 476   2f6c0efd-84b7-d04a-cb1d-a5b98d4d45a9       False              NaN
# 477   2f89b7e7-51eb-ea5c-7141-42b83f35760f       False              NaN
# 478   2fa4c905-b0c7-1cb8-20af-037bc38994ec       False              NaN
# 479   2fa9f745-e7e7-413b-f1a2-a83a9324da77       False              NaN
# 480   2fc43bb4-8085-2656-dcbb-c17b3a7094f3       False              NaN
# 481   2fcd0228-e380-ad3d-4fa7-e236c92b414f        True      233604007.0
# 482   2fd8df61-2653-2bc0-b48d-e000743d0b45       False              NaN
# 483   2fdc69a7-2d71-e171-0b36-d5da65ce4904       False              NaN
# 484   2fdd3784-55c3-5214-036a-acb4f891db81       False              NaN
# 485   2ff6908b-0dfd-7af1-5b64-485a3592b33f       False              NaN
# 486   3013a2e6-4d66-d9fe-3446-a681a0f90d10       False              NaN
# 487   303d86f3-2a4f-4547-b7aa-7d062195afda       False              NaN
# 488   304a3ddf-b583-12fe-29ff-3839dd42c943       False              NaN
# 489   3071f6e4-3ee1-776b-f8b9-589972baead2       False              NaN
# 490   307fb865-bab9-5ba0-1410-094c8596ed62       False              NaN
# 491   30c0a35d-896f-0f14-6865-4744f5993cdd        True      233604007.0
# 492   30c8ac70-b0d1-a724-673b-4e1477fdb986       False              NaN
# 493   30cf420f-d99b-44ee-5577-244f35f15cbb       False              NaN
# 494   30e9159f-ca3f-a34f-6f58-ab550f3a9094       False              NaN
# 495   30ef9d69-5345-bf19-78b3-d67df722bde5       False              NaN
# 496   30f20507-b054-e94f-7d8c-8335cfda83ed       False              NaN
# 497   3121a804-b68c-8ca7-8707-c04c2ef82417       False              NaN
# 498   314ba4f6-5ef7-255d-d6a4-bf01fb612b8b       False              NaN
# 499   3160fd68-33d4-1c9c-003f-15e29d032389       False              NaN
# 500   316ad89e-e355-8acf-63a4-323d9b663846        True      233604007.0
# 501   31783520-b23d-c13d-457e-127a600df87d       False              NaN
# 502   31944c1e-d1ee-39cf-1cd8-5648225ad4b7       False              NaN
# 503   319e350f-1643-8d11-9890-a258bc9306a6        True      233604007.0
# 504   31eda0ad-be44-675b-d276-9df6daca5654       False              NaN
# 505   31fa1b2c-6ed1-5827-7bf3-e9142bb998e8       False              NaN
# 506   320ba478-c9cc-20cc-55c5-6f07ce6e4da7        True      195967001.0
# 507   3214808b-f239-207c-c12c-171c55fffb8e       False              NaN
# 508   321ae0eb-9625-a67f-0197-8a9e42223c62       False              NaN
# 509   32265f94-26ef-1df8-09a0-8031dc283d3b       False              NaN
# 510   322a5d3a-a333-92ca-ee48-80e7ed0e60d0       False              NaN
# 511   3231347f-416a-e966-fb91-572643590205       False              NaN
# 512   3278fe09-9d26-f461-b11c-57c15f624cf9       False              NaN
# 513   3285e875-b5a8-7a3c-fbcc-58ca1349c4a5       False              NaN
# 514   32b5dae7-f5d2-5213-fe94-e1dca646d981       False              NaN
# 515   32bc173d-aaa6-72f8-23e3-da055857aae4       False              NaN
# 516   32e69543-19e6-96ec-b578-57b970f73b39       False              NaN
# 517   32f9fee2-8847-0559-1dc8-f6c27f272eaa       False              NaN
# 518   331043bc-1e3b-5941-c463-acdf07f95ae7       False              NaN
# 519   3316e7dd-c1b1-d12d-f01f-2ba00523af63        True      233604007.0
# 520   331df3d2-3c01-759f-a6e5-89433a3c8835       False              NaN
# 521   33224e79-ac4c-850e-5488-9dc059623142        True      233604007.0
# 522   3323f479-1363-61ea-0bff-6dcfd44e35b5       False              NaN
# 523   3325c283-c1dc-786d-aaef-91e26d558f3a       False              NaN
# 524   3349f6e0-ccbd-00ef-5ad0-024856e71e00       False              NaN
# 525   33686256-28b4-6fa5-b62e-2ebfe89a33bd       False              NaN
# 526   3374c5a2-4178-e2ba-efcd-e6891de7fa18       False              NaN
# 527   33768c52-05cf-9a62-d377-5cd89caf6301       False              NaN
# 528   337c18a1-d303-474f-cd91-d579b2bc8842       False              NaN
# 529   338c1bbb-f499-e3a6-dd70-685fa66943b9       False              NaN
# 530   3390ce41-17cd-febf-e376-8233463539b2       False              NaN
# 531   33a6d4b1-9c9e-fae5-6c15-7e66add6ce25       False              NaN
# 532   33a778fd-fdf9-cea9-bec9-6832ad4541aa       False              NaN
# 533   33c02e90-0316-a553-0abf-171881617554       False              NaN
# 534   33d7da0c-b8cd-86c6-da1a-c90b25030ad6       False              NaN
# 535   33d90254-4aa7-2def-a1fd-2bd60a1bac40        True      233604007.0
# 536   342aa727-5db1-c2e2-5860-a013e7ffc83a        True      233604007.0
# 537   34353603-5960-1d7b-c3ea-84afda07f6d1       False              NaN
# 538   3444cd75-642b-7db9-8777-57572e729963       False              NaN
# 539   34671e1e-5632-5ed1-2b06-7668ce9d4d05        True      185086009.0
# 540   348a30f5-0d80-cbc2-406d-dd4446767f43        True      233604007.0
# 541   34b84944-e0f0-0b1a-74f7-74349bb0b8c3       False              NaN
# 542   34e84dc3-96e4-aac3-6be2-ebc3c92fcc93       False              NaN
# 543   35131ee9-4012-ebc5-31d0-f2197161cdd7       False              NaN
# 544   354881d7-8dc2-afeb-3fd7-74998b574ebc       False              NaN
# 545   35522ba4-e0cd-e046-de9b-5b39dc68ca67       False              NaN
# 546   3555368f-95c4-4b24-c810-51a9befaf195       False              NaN
# 547   355a7673-efe8-4aaf-181d-98127ac64309       False              NaN
# 548   35756998-4e64-0166-9b42-888a6a4e0f83       False              NaN
# 549   3578618a-62c4-83a7-8b8d-384ba4be145e       False              NaN
# 550   3598190d-9189-8d2e-d389-27b7ec37c0f5       False              NaN
# 551   35b1e5b9-2580-c38d-dc65-eed10cac49da       False              NaN
# 552   35d0910c-a248-70cd-1ea5-12e483f96dcb       False              NaN
# 553   35d56a9e-258b-e2dc-1fbf-ef4c832a62d1       False              NaN
# 554   35f6bc9d-79f4-c3a7-40ea-52b2d27a9234       False              NaN
# 555   364abb43-6625-45b0-dde2-8ed8ab804944        True      233604007.0
# 556   3653e396-3795-90ce-d833-3ad97d0ffe61       False              NaN
# 557   3663de04-631f-795f-f078-b81491d8de59        True      233604007.0
# 558   36791b35-8f87-63cb-f380-ec98e91aa87b       False              NaN
# 559   36886185-51ec-5b2d-0200-0e785001baf8       False              NaN
# 560   36b061a7-55af-6a8d-5854-dddb5221cedc       False              NaN
# 561   36b6f95a-0ab8-d3aa-5ecf-4b43addf769a       False              NaN
# 562   36c59fb5-8b8a-b4b1-44a2-63cdcbe432eb        True      233604007.0
# 563   36ca767b-3f44-cfd2-a48e-4dd30fc55976       False              NaN
# 564   36f1e6fc-9690-3ccd-5347-d46472c3f456       False              NaN
# 565   370027df-1036-775e-e40c-09fc45bdd29d       False              NaN
# 566   3736ea31-e822-5189-ef0e-ac5ac39f4821       False              NaN
# 567   37539f33-519b-490d-5ed0-fc9c854092ee        True      233604007.0
# 568   37a2a064-6c7a-d2b4-7747-5ca6a63105ec       False              NaN
# 569   37ddd283-1eb8-fe7a-b9e7-6e322d2fa8df       False              NaN
# 570   380c454a-bf23-64b6-2a2e-5c66b648189f       False              NaN
# 571   3841f3ea-c517-58b4-ad7e-84a032af80ee       False              NaN
# 572   3846a30e-6e53-c521-d0cb-a0d76735ab3e       False              NaN
# 573   3854c2ea-24a8-1aaa-9d17-3a5c09a10a58       False              NaN
# 574   38601a65-4b4f-1c85-cdd5-354d80e14628        True      233604007.0
# 575   38748f19-b0dc-6498-1c23-f7284cfbf237       False              NaN
# 576   38a9e5a0-30f4-02c6-7858-c273985e12b4        True      185086009.0
# 577   38d06ba3-8410-0eb4-fbf8-d223e590bdee        True      233604007.0
# 578   38f9b2af-728b-f4ea-7d45-1f6e21b027cf        True      233604007.0
# 579   3904cb3e-8d13-255f-e4ea-cd4685e1acac       False              NaN
# 580   390f6501-b64f-091a-42c4-47de9c090689       False              NaN
# 581   39299175-c52d-d3ef-fe2a-0e170b25eefd       False              NaN
# 582   3941a7de-5cd9-364e-b7af-67b1c5c75853        True      233604007.0
# 583   395afcc2-8285-4b43-5dc4-614cb461fd3b       False              NaN
# 584   397a0388-bcdd-2016-843e-e942cc280440       False              NaN
# 585   39967125-0417-315a-a0ba-ccfe6736e943       False              NaN
# 586   3a094465-d995-394d-7774-3473b71fac56       False              NaN
# 587   3a0a2f37-ca2f-34af-7a9b-0f718750ebbe        True      233604007.0
# 588   3a10a198-fded-53d7-398c-f98bb0728a38       False              NaN
# 589   3a8d5181-bb73-337d-f8cb-ea19f1c1b561        True      185086009.0
# 590   3aae2817-f6cd-ed5a-b7ab-b984a074e0b8       False              NaN
# 591   3ab9ef09-e9f2-2d73-13e6-9bbd2fc9c907       False              NaN
# 592   3abc9dab-117d-0a21-d7db-3b9047fce056       False              NaN
# 593   3ac39c9b-a96c-aef2-455f-2437141db2a1       False              NaN
# 594   3ac8e77d-5f2f-d96a-0acc-570afb84f662       False              NaN
# 595   3ad0ef12-e5a7-5cbe-d677-cf97c08f38bc       False              NaN
# 596   3ad80d95-5269-a5b1-b802-b0dce58d3703        True      233604007.0
# 597   3ae5c783-f4fb-0d00-0ba4-1c436888105a       False              NaN
# 598   3afe425d-539f-afab-b079-011098d912a4       False              NaN
# 599   3b032d79-6286-5f49-4d78-bc0a2ed730e5       False              NaN
# 600   3b14e10e-a77a-fda3-00df-45807105396a       False              NaN
# 601   3b19bb3c-cb54-2020-6234-491a78af38ad       False              NaN
# 602   3b1d00f2-ab76-d753-407e-16fb83a05d7c       False              NaN
# 603   3b4105e1-eb16-c3f7-fbc5-e98698c3890b       False              NaN
# 604   3b5ac959-47c2-f9b3-32e6-717967ac61bc       False              NaN
# 605   3b79fa50-ca23-b752-c292-9ba4cac97377       False              NaN
# 606   3b899a93-3e82-0eab-f072-03538a062f30       False              NaN
# 607   3bcc7625-b273-9f49-bce0-569916dd75c8       False              NaN
# 608   3bdd3088-efa9-5b6e-84b1-e79289a55780       False              NaN
# 609   3bdec332-314a-54a3-9b89-b303af1320ac       False              NaN
# 610   3beacb27-ebeb-e93f-126d-d112427febb0       False              NaN
# 611   3bf9510a-ba35-372d-1594-f4241c5016b6       False              NaN
# 612   3c6984cb-ce76-520e-eccb-29c1b432b5a3        True      233604007.0
# 613   3c6f5aae-28d8-3387-0fb7-34ada4630982       False              NaN
# 614   3c6f6dad-3e25-3ec4-5520-f153cf040ad8       False              NaN
# 615   3c79fb86-0e3e-5ff7-6cab-3cfbdb250de7       False              NaN
# 616   3c96497f-cc4c-4ef8-40aa-29e8c1418345       False              NaN
# 617   3caf4b83-95ab-b93a-b057-b096704fafab        True      185086009.0
# 618   3cc78a58-b6ea-36fb-ea65-bb84589f38f5       False              NaN
# 619   3cee6d53-5a36-6019-3f20-78bf7ff24358       False              NaN
# 620   3cf6c44b-ca4b-0a4d-96f9-37fbb8d8eeb1       False              NaN
# 621   3cf8e919-400c-4c26-797a-df43937cac63        True      185086009.0
# 622   3cfcd83f-5622-8741-f5a3-de07d46a6ec7       False              NaN
# 623   3d0f50eb-cc49-3599-286e-40af22bb439c       False              NaN
# 624   3d308ccb-7d8a-d116-0722-bb9bc78dfe9d       False              NaN
# 625   3d690062-bb05-7597-3e7f-a57a3d6fc318       False              NaN
# 626   3d724a7c-279a-6df2-21e1-7e53ae3f88e2        True      233604007.0
# 627   3d9f549f-b65d-8ca7-7b10-a96d759e5c8d       False              NaN
# 628   3da3ad37-fd16-ab48-c6e0-a2c604e93caf       False              NaN
# 629   3dac9d84-b36e-4981-75a5-1867141b2b7a       False              NaN
# 630   3db77db9-fa11-d782-8c10-847296194ed2       False              NaN
# 631   3ddd9f80-f2da-eddb-97b1-9796deee7b8c       False              NaN
# 632   3df9dc29-fbde-5828-4739-bb5caf17bd38        True      233604007.0
# 633   3e05f825-7a80-669a-544d-7ed9c19d9ee9       False              NaN
# 634   3e335097-5a76-2835-e93f-cc9234286a42       False              NaN
# 635   3e5c2812-1541-1dee-acf4-2efb6df69e43       False              NaN
# 636   3e78c108-9a47-012c-3c1e-e1f2d3313abc       False              NaN
# 637   3e834f22-c366-4385-cbee-c11e3feb329a        True      233604007.0
# 638   3ea8bb2c-dd6f-ab77-a4b7-a40f46df66eb       False              NaN
# ...
# 2408         NaN         NaN
# 2409         NaN         NaN
# 2410         NaN         NaN
# 2411         NaN         NaN
# 2412         NaN         NaN
# 2413         NaN         NaN
# 2414         NaN         NaN
# 2415         NaN         NaN
# 2416         NaN         NaN
# 2417         NaN         NaN
# 2418         NaN         NaN
# 2419         NaN         NaN
# 2420         NaN         NaN
# 2421         NaN         NaN
# 2422         NaN         NaN
# 2423         NaN         NaN
# 2424         NaN         NaN
# 2425         NaN         NaN
# 2426         NaN         NaN
# 2427         NaN         NaN
# 2428         NaN         NaN
# 2429         NaN         NaN
# 2430         NaN         NaN
# 2431         NaN         NaN
# 2432         NaN         NaN
# 2433         NaN         NaN
# 2434         NaN         NaN
# 2435         NaN         NaN
# 2436         NaN         NaN
# 2437         NaN         NaN
# 2438         NaN         NaN
# 2439         NaN         NaN
# 2440         NaN         NaN
# 2441         NaN         NaN
# 2442         NaN         NaN
# 2443         NaN         NaN
# 2444         NaN         NaN
# 2445         NaN         NaN
# 2446         NaN         NaN
# 2447         NaN         NaN
# 2448         NaN         NaN
# 2449         NaN         NaN
# 2450         NaN         NaN
# 2451         NaN         NaN
# 2452         NaN         NaN
# 2453         NaN         NaN
# 2454         NaN         NaN
# 2455         NaN         NaN
# 2456         NaN         NaN
# 2457         NaN         NaN
# 2458         NaN         NaN
# 2459         NaN         NaN
# 2460         NaN         NaN
# 2461         NaN         NaN
# 2462         NaN         NaN
# 2463         NaN         NaN
# 2464         NaN         NaN
# 2465         NaN         NaN
# 2466         NaN         NaN
# 2467         NaN         NaN
# 2468         NaN         NaN
# 2469         NaN         NaN
# 2470         NaN         NaN
# 2471         NaN         NaN
# 2472         NaN         NaN
# 2473         NaN         NaN
# 2474         NaN         NaN
# 2475         NaN         NaN
# 2476         NaN         NaN
# 2477         NaN         NaN
# 2478         NaN         NaN
# 2479         NaN         NaN
# 2480         NaN         NaN
# 2481         NaN         NaN
# 2482         NaN         NaN
# 2483         NaN         NaN
# 2484         NaN         NaN
# 2485         NaN         NaN
# 2486         NaN         NaN
# 2487         NaN         NaN
# 2488         NaN         NaN
# 2489         NaN         NaN
# 2490         NaN         NaN
# 2491         NaN         NaN
# 2492         NaN         NaN
# 2493         NaN         NaN
# 2494         NaN         NaN
# 2495         NaN         NaN
# 2496         NaN         NaN
# 2497         NaN         NaN
# 2498         NaN         NaN
# 2499         NaN         NaN
# 2500         NaN         NaN
# 2501         NaN         NaN
# 2502         NaN         NaN
# 2503         NaN         NaN
# 2504         NaN         NaN
# 2505         NaN         NaN
# 2506         NaN         NaN
# 2507         NaN         NaN
# 2508         NaN         NaN
# 2509         NaN         NaN
# 2510         NaN         NaN
# 2511         NaN         NaN
# 2512         NaN         NaN
# 2513         NaN         NaN
# 2514         NaN         NaN
# 2515         NaN         NaN
# 2516         NaN         NaN
# 2517         NaN         NaN
# 2518         NaN         NaN
# 2519         NaN         NaN
# 2520         NaN         NaN
# 2521         NaN         NaN
# 2522         NaN         NaN
# 2523         NaN         NaN
# 2524         NaN         NaN
# 2525         NaN         NaN
# 2526         NaN         NaN
# 2527         NaN         NaN
# 2528         NaN         NaN
# 2529         NaN         NaN
# 2530         NaN         NaN
# 2531         NaN         NaN
# 2532         NaN         NaN
# 2533         NaN         NaN
# 2534         NaN         NaN
# 2535         NaN         NaN
# 2536         NaN         NaN
# 2537         NaN         NaN
# 2538         NaN         NaN
# 2539         NaN         NaN
# 2540         NaN         NaN
# 2541         NaN         NaN
# 2542         NaN         NaN
# 2543         NaN         NaN
# 2544         NaN         NaN
# 2545         NaN         NaN
# 2546         NaN         NaN
# 2547         NaN         NaN
# 2548         NaN         NaN
# 2549         NaN         NaN
# 2550         NaN         NaN
# 2551         NaN         NaN
# 2552         NaN         NaN
# 2553         NaN         NaN
# 2554         NaN         NaN
# 2555         NaN         NaN
# 2556         NaN         NaN
# 2557         NaN         NaN
# 2558         NaN         NaN
# 2559         NaN         NaN
# 2560         NaN         NaN
# 2561         NaN         NaN
# 2562         NaN         NaN
# 2563         NaN         NaN
# 2564         NaN         NaN
# 2565         NaN         NaN
# 2566         NaN         NaN
# 2567         NaN         NaN
# 2568         NaN         NaN
# 2569         NaN         NaN
# 2570         NaN         NaN
# 2571         NaN         NaN
# 2572         NaN         NaN
# 2573         NaN         NaN
# 2574         NaN         NaN
# 2575         NaN         NaN
# 2576         NaN         NaN
# 2577         NaN         NaN
# 2578         NaN         NaN
# 2579         NaN         NaN
# 2580         NaN         NaN
# 2581         NaN         NaN
# 2582         NaN         NaN
# 2583         NaN         NaN
# 2584         NaN         NaN
# 2585         NaN         NaN
# 2586         NaN         NaN
# 2587         NaN         NaN
# 2588         NaN         NaN
# 2589         NaN         NaN
# 2590         NaN         NaN
# 2591         NaN         NaN
# 2592         NaN         NaN
# 2593         NaN         NaN
# 2594         NaN         NaN
# 2595         NaN         NaN
# 2596         NaN         NaN
# 2597         NaN         NaN
# 2598         NaN         NaN
# 2599         NaN         NaN
# 2600         NaN         NaN
# 2601         NaN         NaN
# 2602         NaN         NaN
# 2603         NaN         NaN
# 2604         NaN         NaN
# 2605         NaN         NaN
# 2606         NaN         NaN
# 2607         NaN         NaN
# 2608         NaN         NaN
# 2609         NaN         NaN
# 2610         NaN         NaN
# 2611         NaN         NaN
# 2612         NaN         NaN
# 2613         NaN         NaN
# 2614         NaN         NaN
# 2615         NaN         NaN
# 2616         NaN         NaN
# 2617         NaN         NaN
# 2618         NaN         NaN
# 2619         NaN         NaN
# 2620         NaN         NaN
# 2621         NaN         NaN
# 2622         NaN         NaN
# 2623         NaN         NaN
# 2624         NaN         NaN
# 2625         NaN         NaN
# 2626         NaN         NaN
# 2627         NaN         NaN
# 2628         NaN         NaN
# 2629         NaN         NaN
# 2630         NaN         NaN
#
# [2631 rows x 82 columns]
# Columns in df: ['patient_id', 'lung_label', 'first_lung_code', 'first_lung_description', 'BIRTHDATE', 'DEATHDATE', 'SSN', 'DRIVERS', 'PASSPORT', 'PREFIX', 'FIRST', 'LAST', 'SUFFIX', 'MAIDEN', 'MARITAL', 'RACE', 'ETHNICITY', 'GENDER', 'BIRTHPLACE', 'ADDRESS', 'CITY', 'STATE', 'COUNTY', 'ZIP', 'LAT', 'LON', 'HEALTHCARE_EXPENSES', 'HEALTHCARE_COVERAGE', 'first_start', 'age_event', 'age_current', 'num_comorbidities', 'race_asian', 'race_black', 'race_hawaiian', 'race_native', 'race_other', 'race_white', 'ethnicity_hispanic', 'ethnicity_nonhispanic', 'mean_29463-7', 'mean_39156-5', 'mean_59576-9', 'mean_63512-8', 'mean_63586-2', 'mean_70274-6', 'mean_72514-3', 'mean_75626-2', 'mean_8302-2', 'mean_8462-4', 'mean_8480-6', 'mean_8867-4', 'mean_9279-1', 'min_29463-7', 'min_39156-5', 'min_59576-9', 'min_63512-8', 'min_63586-2', 'min_70274-6', 'min_72514-3', 'min_75626-2', 'min_8302-2', 'min_8462-4', 'min_8480-6', 'min_8867-4', 'min_9279-1', 'max_29463-7', 'max_39156-5', 'max_59576-9', 'max_63512-8', 'max_63586-2', 'max_70274-6', 'max_72514-3', 'max_75626-2', 'max_8302-2', 'max_8462-4', 'max_8480-6', 'max_8867-4', 'max_9279-1', 'mean_55758-7', 'min_55758-7', 'max_55758-7']
#
# Dropped columns: ['SSN', 'DRIVERS', 'PASSPORT', 'PREFIX', 'SUFFIX', 'MARITAL', 'BIRTHPLACE', 'ADDRESS', 'CITY', 'STATE', 'COUNTY', 'ZIP', 'LAT', 'LON', 'HEALTHCARE_EXPENSES', 'HEALTHCARE_COVERAGE', 'mean_55758‑7', 'min_55758‑7', 'max_55758‑7']
#
# Lung_label counts:
# lung_label
# False    2164
# True      467
# Name: count, dtype: int64
#
# Lung_label proportions:
# lung_label
# False    0.822501
# True     0.177499
# Name: proportion, dtype: float64
#
# Numeric feature summary:
#                     count          mean           std           min  \
# first_lung_code     467.0  2.253858e+08  1.812149e+07  1.850860e+08
# age_event          2631.0  1.815047e+01  3.592307e-02  1.800958e+01
# age_current        2631.0  7.226436e+01  1.638294e+01  2.779192e+01
# num_comorbidities  2631.0  1.956670e+01  5.546487e+00  7.000000e+00
# mean_29463-7          2.0  5.510000e+01  9.899495e-01  5.440000e+01
# mean_39156-5          2.0  2.020000e+01  2.121320e+00  1.870000e+01
# mean_59576-9          2.0  3.145000e+01  3.288047e+01  8.200000e+00
# mean_63512-8          2.0  4.000000e+00  2.828427e+00  2.000000e+00
# mean_63586-2          2.0  1.969500e+04  2.388041e+04  2.809000e+03
# mean_70274-6          2.0  1.000000e+00  1.414214e+00  0.000000e+00
# mean_72514-3          2.0  5.000000e-01  7.071068e-01  0.000000e+00
# mean_75626-2          2.0  2.000000e+00  1.414214e+00  1.000000e+00
# mean_8302-2           2.0  1.654500e+02  7.000357e+00  1.605000e+02
# mean_8462-4           2.0  8.600000e+01  5.656854e+00  8.200000e+01
# mean_8480-6           2.0  1.365000e+02  1.343503e+01  1.270000e+02
# mean_8867-4           2.0  7.200000e+01  1.555635e+01  6.100000e+01
# mean_9279-1           2.0  1.450000e+01  7.071068e-01  1.400000e+01
# min_29463-7           2.0  5.510000e+01  9.899495e-01  5.440000e+01
# min_39156-5           2.0  2.020000e+01  2.121320e+00  1.870000e+01
# min_59576-9           2.0  3.145000e+01  3.288047e+01  8.200000e+00
# min_63512-8           2.0  4.000000e+00  2.828427e+00  2.000000e+00
# min_63586-2           2.0  1.969500e+04  2.388041e+04  2.809000e+03
# min_70274-6           2.0  1.000000e+00  1.414214e+00  0.000000e+00
# min_72514-3           2.0  5.000000e-01  7.071068e-01  0.000000e+00
# min_75626-2           2.0  2.000000e+00  1.414214e+00  1.000000e+00
# min_8302-2            2.0  1.654500e+02  7.000357e+00  1.605000e+02
# min_8462-4            2.0  8.600000e+01  5.656854e+00  8.200000e+01
# min_8480-6            2.0  1.365000e+02  1.343503e+01  1.270000e+02
# min_8867-4            2.0  7.200000e+01  1.555635e+01  6.100000e+01
# min_9279-1            2.0  1.450000e+01  7.071068e-01  1.400000e+01
# max_29463-7           2.0  5.510000e+01  9.899495e-01  5.440000e+01
# max_39156-5           2.0  2.020000e+01  2.121320e+00  1.870000e+01
# max_59576-9           2.0  3.145000e+01  3.288047e+01  8.200000e+00
# max_63512-8           2.0  4.000000e+00  2.828427e+00  2.000000e+00
# max_63586-2           2.0  1.969500e+04  2.388041e+04  2.809000e+03
# max_70274-6           2.0  1.000000e+00  1.414214e+00  0.000000e+00
# max_72514-3           2.0  5.000000e-01  7.071068e-01  0.000000e+00
# max_75626-2           2.0  2.000000e+00  1.414214e+00  1.000000e+00
# max_8302-2            2.0  1.654500e+02  7.000357e+00  1.605000e+02
# max_8462-4            2.0  8.600000e+01  5.656854e+00  8.200000e+01
# max_8480-6            2.0  1.365000e+02  1.343503e+01  1.270000e+02
# max_8867-4            2.0  7.200000e+01  1.555635e+01  6.100000e+01
# max_9279-1            2.0  1.450000e+01  7.071068e-01  1.400000e+01
# mean_55758-7          1.0  2.000000e+00           NaN  2.000000e+00
# min_55758-7           1.0  2.000000e+00           NaN  2.000000e+00
# max_55758-7           1.0  2.000000e+00           NaN  2.000000e+00
#
#                             25%           50%           75%           max
# first_lung_code    2.336040e+08  2.336040e+08  2.336040e+08  2.336040e+08
# age_event          1.814921e+01  1.814921e+01  1.815195e+01  1.916769e+01
# age_current        6.051335e+01  7.482546e+01  8.480630e+01  1.028884e+02
# num_comorbidities  1.600000e+01  1.900000e+01  2.200000e+01  4.700000e+01
# mean_29463-7       5.475000e+01  5.510000e+01  5.545000e+01  5.580000e+01
# mean_39156-5       1.945000e+01  2.020000e+01  2.095000e+01  2.170000e+01
# mean_59576-9       1.982500e+01  3.145000e+01  4.307500e+01  5.470000e+01
# mean_63512-8       3.000000e+00  4.000000e+00  5.000000e+00  6.000000e+00
# mean_63586-2       1.125200e+04  1.969500e+04  2.813800e+04  3.658100e+04
# mean_70274-6       5.000000e-01  1.000000e+00  1.500000e+00  2.000000e+00
# mean_72514-3       2.500000e-01  5.000000e-01  7.500000e-01  1.000000e+00
# mean_75626-2       1.500000e+00  2.000000e+00  2.500000e+00  3.000000e+00
# mean_8302-2        1.629750e+02  1.654500e+02  1.679250e+02  1.704000e+02
# mean_8462-4        8.400000e+01  8.600000e+01  8.800000e+01  9.000000e+01
# mean_8480-6        1.317500e+02  1.365000e+02  1.412500e+02  1.460000e+02
# mean_8867-4        6.650000e+01  7.200000e+01  7.750000e+01  8.300000e+01
# mean_9279-1        1.425000e+01  1.450000e+01  1.475000e+01  1.500000e+01
# min_29463-7        5.475000e+01  5.510000e+01  5.545000e+01  5.580000e+01
# min_39156-5        1.945000e+01  2.020000e+01  2.095000e+01  2.170000e+01
# min_59576-9        1.982500e+01  3.145000e+01  4.307500e+01  5.470000e+01
# min_63512-8        3.000000e+00  4.000000e+00  5.000000e+00  6.000000e+00
# min_63586-2        1.125200e+04  1.969500e+04  2.813800e+04  3.658100e+04
# min_70274-6        5.000000e-01  1.000000e+00  1.500000e+00  2.000000e+00
# min_72514-3        2.500000e-01  5.000000e-01  7.500000e-01  1.000000e+00
# min_75626-2        1.500000e+00  2.000000e+00  2.500000e+00  3.000000e+00
# min_8302-2         1.629750e+02  1.654500e+02  1.679250e+02  1.704000e+02
# min_8462-4         8.400000e+01  8.600000e+01  8.800000e+01  9.000000e+01
# min_8480-6         1.317500e+02  1.365000e+02  1.412500e+02  1.460000e+02
# min_8867-4         6.650000e+01  7.200000e+01  7.750000e+01  8.300000e+01
# min_9279-1         1.425000e+01  1.450000e+01  1.475000e+01  1.500000e+01
# max_29463-7        5.475000e+01  5.510000e+01  5.545000e+01  5.580000e+01
# max_39156-5        1.945000e+01  2.020000e+01  2.095000e+01  2.170000e+01
# max_59576-9        1.982500e+01  3.145000e+01  4.307500e+01  5.470000e+01
# max_63512-8        3.000000e+00  4.000000e+00  5.000000e+00  6.000000e+00
# max_63586-2        1.125200e+04  1.969500e+04  2.813800e+04  3.658100e+04
# max_70274-6        5.000000e-01  1.000000e+00  1.500000e+00  2.000000e+00
# max_72514-3        2.500000e-01  5.000000e-01  7.500000e-01  1.000000e+00
# max_75626-2        1.500000e+00  2.000000e+00  2.500000e+00  3.000000e+00
# max_8302-2         1.629750e+02  1.654500e+02  1.679250e+02  1.704000e+02
# max_8462-4         8.400000e+01  8.600000e+01  8.800000e+01  9.000000e+01
# max_8480-6         1.317500e+02  1.365000e+02  1.412500e+02  1.460000e+02
# max_8867-4         6.650000e+01  7.200000e+01  7.750000e+01  8.300000e+01
# max_9279-1         1.425000e+01  1.450000e+01  1.475000e+01  1.500000e+01
# mean_55758-7       2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
# min_55758-7        2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
# max_55758-7        2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
#
# Categorical feature counts:
#                         unique_values
# patient_id                       2631
# first_lung_description              4
# BIRTHDATE                        1928
# DEATHDATE                        1427
# FIRST                            1871
# LAST                              602
# MAIDEN                            471
# RACE                                6
# ETHNICITY                           2
# GENDER                              2
# first_start                      2070

# %%
# Cell 16: Cleaned Cohort & Column List

# 1) Show the updated column list
print("Columns in cleaned df:", df.columns.tolist(), "\n")

# 2) Preview the first few rows of the cleaned DataFrame
pd.set_option('display.max_columns', None)
display(df.head())
pd.reset_option('display.max_columns')
# Out:
# Columns in cleaned df: ['patient_id', 'lung_label', 'first_lung_code', 'first_lung_description', 'BIRTHDATE', 'DEATHDATE', 'FIRST', 'LAST', 'MAIDEN', 'RACE', 'ETHNICITY', 'GENDER', 'first_start', 'age_event', 'age_current', 'num_comorbidities', 'race_asian', 'race_black', 'race_hawaiian', 'race_native', 'race_other', 'race_white', 'ethnicity_hispanic', 'ethnicity_nonhispanic', 'mean_29463-7', 'mean_39156-5', 'mean_59576-9', 'mean_63512-8', 'mean_63586-2', 'mean_70274-6', 'mean_72514-3', 'mean_75626-2', 'mean_8302-2', 'mean_8462-4', 'mean_8480-6', 'mean_8867-4', 'mean_9279-1', 'min_29463-7', 'min_39156-5', 'min_59576-9', 'min_63512-8', 'min_63586-2', 'min_70274-6', 'min_72514-3', 'min_75626-2', 'min_8302-2', 'min_8462-4', 'min_8480-6', 'min_8867-4', 'min_9279-1', 'max_29463-7', 'max_39156-5', 'max_59576-9', 'max_63512-8', 'max_63586-2', 'max_70274-6', 'max_72514-3', 'max_75626-2', 'max_8302-2', 'max_8462-4', 'max_8480-6', 'max_8867-4', 'max_9279-1', 'mean_55758-7', 'min_55758-7', 'max_55758-7']
#                              patient_id  lung_label  first_lung_code  \
# 0  005444f1-853d-ad2e-2ee6-b772b4bb8014       False              NaN
# 1  007b9335-08e2-c478-a79a-d9d4b6e88f62       False              NaN
# 2  009f3a51-db42-bb8d-daad-a03c46387522       False              NaN
# 3  00ab49d7-9776-b5fd-abbd-5151ca805afb       False              NaN
# 4  00b9b7eb-5bd2-718c-4966-2dabcc2a1528       False              NaN
#
#   first_lung_description   BIRTHDATE   DEATHDATE         FIRST          LAST  \
# 0                    NaN  1927-02-07         NaN     Sydney660     Zulauf375
# 1                    NaN  1926-01-19  1985-08-31      Bryon392    Wiegand701
# 2                    NaN  1927-01-24  1981-09-23  Marcelene872    Kshlerin58
# 3                    NaN  1926-01-07  2007-01-29     Vaughn909      Kunde533
# 4                    NaN  1933-10-15  2021-07-05    Anthony633  Ankunding277
#
#       MAIDEN   RACE    ETHNICITY GENDER          first_start  age_event  \
# 0        NaN  white  nonhispanic      M  1945-04-03 04:23:21  18.151951
# 1        NaN  white  nonhispanic      M  1944-03-15 04:23:09  18.151951
# 2  Brekke496  white  nonhispanic      F  1945-03-20 01:16:54  18.151951
# 3        NaN  white  nonhispanic      M  1944-01-14 02:30:39  18.017796
# 4        NaN  white  nonhispanic      M  1951-12-09 13:59:08  18.149213
#
#    age_current  num_comorbidities  race_asian  race_black  race_hawaiian  \
# 0    98.245038                 24       False       False          False
# 1    59.613963                 16       False       False          False
# 2    54.663929                 14       False       False          False
# 3    81.059548                 21       False       False          False
# 4    87.720739                 12       False       False          False
#
#    race_native  race_other  race_white  ethnicity_hispanic  \
# 0        False       False        True               False
# 1        False       False        True               False
# 2        False       False        True               False
# 3        False       False        True               False
# 4        False       False        True               False
#
#    ethnicity_nonhispanic  mean_29463-7  mean_39156-5  mean_59576-9  \
# 0                   True           NaN           NaN           NaN
# 1                   True           NaN           NaN           NaN
# 2                   True           NaN           NaN           NaN
# 3                   True           NaN           NaN           NaN
# 4                   True           NaN           NaN           NaN
#
#    mean_63512-8  mean_63586-2  mean_70274-6  mean_72514-3  mean_75626-2  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    mean_8302-2  mean_8462-4  mean_8480-6  mean_8867-4  mean_9279-1  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    min_29463-7  min_39156-5  min_59576-9  min_63512-8  min_63586-2  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    min_70274-6  min_72514-3  min_75626-2  min_8302-2  min_8462-4  min_8480-6  \
# 0          NaN          NaN          NaN         NaN         NaN         NaN
# 1          NaN          NaN          NaN         NaN         NaN         NaN
# 2          NaN          NaN          NaN         NaN         NaN         NaN
# 3          NaN          NaN          NaN         NaN         NaN         NaN
# 4          NaN          NaN          NaN         NaN         NaN         NaN
#
#    min_8867-4  min_9279-1  max_29463-7  max_39156-5  max_59576-9  max_63512-8  \
# 0         NaN         NaN          NaN          NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN          NaN          NaN
#
#    max_63586-2  max_70274-6  max_72514-3  max_75626-2  max_8302-2  max_8462-4  \
# 0          NaN          NaN          NaN          NaN         NaN         NaN
# 1          NaN          NaN          NaN          NaN         NaN         NaN
# 2          NaN          NaN          NaN          NaN         NaN         NaN
# 3          NaN          NaN          NaN          NaN         NaN         NaN
# 4          NaN          NaN          NaN          NaN         NaN         NaN
#
#    max_8480-6  max_8867-4  max_9279-1  mean_55758-7  min_55758-7  max_55758-7
# 0         NaN         NaN         NaN           NaN          NaN          NaN
# 1         NaN         NaN         NaN           NaN          NaN          NaN
# 2         NaN         NaN         NaN           NaN          NaN          NaN
# 3         NaN         NaN         NaN           NaN          NaN          NaN
# 4         NaN         NaN         NaN           NaN          NaN          NaN

# %%
### Modeling Pipeline + Evaluation

# %%
# Cell 16b: Define targets (binary + multiclass) and do a single stratified train/test split

import pandas as pd
from sklearn.model_selection import train_test_split

# 1) Load the enriched cohort
df = pd.read_csv('cohort_enriched.csv')

# 2) Binary target: any lung disease
y_binary = df['lung_label'].astype(int)

# 3) Multiclass target: specific disease at first encounter
#    — THIS IS YOUR “step 3” CODE —
#    First cast to integer (drop NaN), then map SNOMED CT → labels
df['first_lung_code_int'] = (
    pd.to_numeric(df['first_lung_code'], errors='coerce')
      .dropna().astype(int)
)
mapping = {
    233604007: 'pneumonia',
    195967001: 'asthma',
    185086009: 'COPD'
}
df['disease_type'] = (
    df['first_lung_code_int']
      .map(mapping)
      .fillna('none')
)
y_multi = pd.Categorical(
    df['disease_type'],
    categories=['none','pneumonia','asthma','COPD']
)

y_multi_code  = y_multi.codes  # 0,1,2,3

# 4) Feature matrix
X = df.drop(columns=[
    'lung_label',
    'first_lung_code',
    'first_lung_description',
    'first_lung_code_int',
    'disease_type'
])

# 5) Single stratified split for both targets
X_train, X_test, \
yb_train, yb_test, \
ymc_train, ymc_test = train_test_split(
    X, 
    y_binary,
    y_multi_code,
    stratify=y_binary,
    test_size=0.1,
    random_state=42
)

print("Shapes:",
      X_train.shape,
      yb_train.shape,
      ym_train.shape,
      ymc_train.shape)
# Out:
# Shapes: (2367, 79) (2367,) (2367,) (2367,)

# %%
pip install imbalanced-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\yanis\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip
# Requirement already satisfied: imbalanced-learn in c:\users\yanis\appdata\local\programs\python\python313\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\yanis\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (2.2.2)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\yanis\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (1.15.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\yanis\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\yanis\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\yanis\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\yanis\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (3.5.0)

# %%
# Cell 17 (edited): Modeling Pipelines + GridSearchCV (5‑fold CV) for Binary Lung‑Disease Prediction

import pandas as pd
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# Try to import XGBoost
try:
    from xgboost import XGBClassifier
    has_xgb = True
except ImportError:
    print("Warning: xgboost not installed, skipping that model.")
    has_xgb = False

# Define classifiers and hyperparameter grids
model_specs = {
    'LogisticRegression': {
        'estimator': LogisticRegression(solver='liblinear',
                                        max_iter=1000,
                                        random_state=42),
        'param_grid': {
            'clf__C':       [0.01, 0.1, 1, 10],
            'clf__penalty': ['l1', 'l2']
        }
    },
    'RandomForest': {
        'estimator': RandomForestClassifier(random_state=42),
        'param_grid': {
            'clf__n_estimators': [100, 200],
            'clf__max_depth':    [None, 10, 20],
            'clf__class_weight':['balanced', None]
        }
    }
}

if has_xgb:
    model_specs['XGBoost'] = {
        'estimator': XGBClassifier(use_label_encoder=False,
                                   eval_metric='logloss',
                                   random_state=42),
        'param_grid': {
            'clf__n_estimators':  [100, 200],
            'clf__max_depth':     [3, 6],
            'clf__learning_rate': [0.01, 0.1]
        }
    }

best_models = {}
for name, spec in model_specs.items():
    pipe = ImbPipeline([
        ('pre',   preprocessor),    # your ColumnTransformer from Cell 14
        ('smote', SMOTE(random_state=42)),
        ('clf',   spec['estimator'])
    ])
    grid = GridSearchCV(
        pipe,
        spec['param_grid'],
        cv=5,
        scoring='roc_auc',
        n_jobs=-1,
        verbose=1
    )
    print(f"\nRunning GridSearchCV for {name} with SMOTE…")
    grid.fit(X_train, yb_train)
    print(f"→ {name} best CV ROC‑AUC: {grid.best_score_:.3f}")
    print(f"  Best params: {grid.best_params_}\n")
    best_models[name] = grid.best_estimator_
# Out:
# Running GridSearchCV for LogisticRegression with SMOTE…
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# → LogisticRegression best CV ROC‑AUC: 0.655
#   Best params: {'clf__C': 0.01, 'clf__penalty': 'l1'}
#
#
# Running GridSearchCV for RandomForest with SMOTE…
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# → RandomForest best CV ROC‑AUC: 0.682
#   Best params: {'clf__class_weight': 'balanced', 'clf__max_depth': 10, 'clf__n_estimators': 100}
#
#
# Running GridSearchCV for XGBoost with SMOTE…
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# → XGBoost best CV ROC‑AUC: 0.707
#   Best params: {'clf__learning_rate': 0.01, 'clf__max_depth': 3, 'clf__n_estimators': 100}
# C:\Users\yanis\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:36:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
# Cell 18: Test‑set Evaluation of Best Models

import numpy as np
from sklearn.metrics import (
    roc_auc_score,
    precision_recall_curve,
    classification_report,
    confusion_matrix,
    auc
)

for name, model in best_models.items():
    y_pred  = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:,1]

    # Overall metrics
    print(f"=== {name} Test Results ===")
    print(classification_report(yb_test, y_pred, digits=3))

    # ROC‐AUC
    roc_auc = roc_auc_score(yb_test, y_proba)
    print(f"ROC‑AUC: {roc_auc:.3f}")

    # Precision‑Recall AUC
    prec, rec, _ = precision_recall_curve(yb_test, y_proba)
    pr_auc = auc(rec, prec)
    print(f"AUPRC:   {pr_auc:.3f}")

    # Compute specificity / sensitivity from confusion matrix
    tn, fp, fn, tp = confusion_matrix(yb_test, y_pred).ravel()
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    print(f"Sensitivity: {sensitivity:.3f}")
    print(f"Specificity: {specificity:.3f}")

    print("Confusion Matrix:")
    print(f" [[TN: {tn}  FP: {fp}]\n  [FN: {fn}  TP: {tp}]]\n")
# Out:
# === LogisticRegression Test Results ===
#               precision    recall  f1-score   support
#
#            0      0.891     0.567     0.693       217
#            1      0.254     0.681     0.370        47
#
#     accuracy                          0.587       264
#    macro avg      0.573     0.624     0.531       264
# weighted avg      0.778     0.587     0.635       264
#
# ROC‑AUC: 0.629
# AUPRC:   0.255
# Sensitivity: 0.681
# Specificity: 0.567
# Confusion Matrix:
#  [[TN: 123  FP: 94]
#   [FN: 15  TP: 32]]
#
# === RandomForest Test Results ===
#               precision    recall  f1-score   support
#
#            0      0.872     0.659     0.751       217
#            1      0.260     0.553     0.354        47
#
#     accuracy                          0.640       264
#    macro avg      0.566     0.606     0.552       264
# weighted avg      0.763     0.640     0.680       264
#
# ROC‑AUC: 0.658
# AUPRC:   0.269
# Sensitivity: 0.553
# Specificity: 0.659
# Confusion Matrix:
#  [[TN: 143  FP: 74]
#   [FN: 21  TP: 26]]
#
# === XGBoost Test Results ===
#               precision    recall  f1-score   support
#
#            0      0.925     0.567     0.703       217
#            1      0.282     0.787     0.416        47
#
#     accuracy                          0.606       264
#    macro avg      0.604     0.677     0.559       264
# weighted avg      0.810     0.606     0.652       264
#
# ROC‑AUC: 0.690
# AUPRC:   0.307
# Sensitivity: 0.787
# Specificity: 0.567
# Confusion Matrix:
#  [[TN: 123  FP: 94]
#   [FN: 10  TP: 37]]

# %%
# Cell 19: Plot ROC and Precision–Recall Curves

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, precision_recall_curve

plt.figure(figsize=(6,5))
for name, model in best_models.items():
    y_proba = model.predict_proba(X_test)[:,1]
    fpr, tpr, _ = roc_curve(yb_test, y_proba)
    plt.plot(fpr, tpr, label=f"{name} (AUC={roc_auc_score(yb_test, y_proba):.2f})")
plt.plot([0,1],[0,1],'k--', label="Chance")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves on Test Set")
plt.legend()
plt.show()

plt.figure(figsize=(6,5))
for name, model in best_models.items():
    y_proba = model.predict_proba(X_test)[:,1]
    prec, rec, _ = precision_recall_curve(yb_test, y_proba)
    plt.plot(rec, prec, label=f"{name} (AP={auc(rec, prec):.2f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curves on Test Set")
plt.legend()
plt.show()

# %%
# Cell 20: Multiclass 5‑fold CV with integer‑coded labels + SMOTE

import pandas as pd
import numpy as np

# use imblearn’s Pipeline so we can insert SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE

from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# Try to import XGBoost
try:
    from xgboost import XGBClassifier
    has_xgb = True
except ImportError:
    has_xgb = False

# ─── 1) Load data & prepare targets ───────────────────────────────────────────
df = pd.read_csv('cohort_enriched.csv')

# ensure first_lung_code_int and disease_type exist as in Cell 16b
df['first_lung_code_int'] = (
    pd.to_numeric(df['first_lung_code'], errors='coerce')
      .dropna().astype(int)
)
mapping = {
    233604007: 'pneumonia',
    195967001: 'asthma',
    13645005:  'COPD'
}
df['disease_type'] = (
    df['first_lung_code_int']
      .map(mapping)
      .fillna('none')
)
y_multi = pd.Categorical(
    df['disease_type'],
    categories=['none','pneumonia','asthma','COPD']
)

# ─── 2) Integer‑encode labels ─────────────────────────────────────────────────
y_multi_code = y_multi.codes  # array of 0,1,2,3

# ─── 3) Feature matrix ───────────────────────────────────────────────────────
X = df.drop(columns=[
    'lung_label',
    'first_lung_code',
    'first_lung_description',
    'first_lung_code_int',
    'disease_type'
])

# ─── 4) CV & scoring setup ───────────────────────────────────────────────────
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scoring = [
    'accuracy',
    'precision_macro',
    'recall_macro',
    'f1_macro',
    'roc_auc_ovr',
]

# ─── 5) Model definitions ────────────────────────────────────────────────────
model_defs = {
    'LogisticRegression': LogisticRegression(
        solver='liblinear', multi_class='ovr',
        max_iter=1000, random_state=42
    ),
    'RandomForest': RandomForestClassifier(
        n_estimators=200, max_depth=10,
        random_state=42
    )
}
if has_xgb:
    model_defs['XGBoost'] = XGBClassifier(
        use_label_encoder=False,
        eval_metric='mlogloss',
        random_state=42
    )

# ─── 6) Run cross_validate with SMOTE in the pipeline ─────────────────────────
results = {}
for name, clf in model_defs.items():
    pipe = ImbPipeline([
        ('pre',   preprocessor),          # from Cell 14
        ('smote', SMOTE(random_state=42, k_neighbors=2)),  # <— balance each training fold
        ('clf',   clf)
    ])
    print(f"\n=== 5‑fold CV for {name} w/ SMOTE ===")
    cv_res = cross_validate(
        pipe,
        X, y_multi_code,
        cv=cv,
        scoring=scoring,
        n_jobs=-1,
        return_train_score=False
    )
    # summarize mean ± std
    summary = {
        metric: f"{cv_res['test_' + metric].mean():.3f} ± {cv_res['test_' + metric].std():.3f}"
        for metric in scoring
    }
    print(pd.Series(summary), "\n")
    results[name] = cv_res
# Out:
# === 5‑fold CV for LogisticRegression w/ SMOTE ===
# C:\Users\yanis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# accuracy           0.341 ± 0.052
# precision_macro    0.373 ± 0.006
# recall_macro       0.455 ± 0.156
# f1_macro           0.254 ± 0.027
# roc_auc_ovr            nan ± nan
# dtype: object
#
#
# === 5‑fold CV for RandomForest w/ SMOTE ===
# C:\Users\yanis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# accuracy           0.616 ± 0.041
# precision_macro    0.382 ± 0.007
# recall_macro       0.401 ± 0.017
# f1_macro           0.360 ± 0.012
# roc_auc_ovr            nan ± nan
# dtype: object
#
#
# === 5‑fold CV for XGBoost w/ SMOTE ===
# C:\Users\yanis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# accuracy           0.753 ± 0.009
# precision_macro    0.386 ± 0.012
# recall_macro       0.394 ± 0.016
# f1_macro           0.388 ± 0.013
# roc_auc_ovr            nan ± nan
# dtype: object

# %%
# ─── Cell 21: Fit final multiclass pipelines on the training set ────────────
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE

# assuming you still have X_train, ym_train from Cell 16b
best_multi_models = {}

for name, clf in model_defs.items():
    pipe = ImbPipeline([
        ('pre',   preprocessor),             
        ('smote', SMOTE(random_state=42, k_neighbors=2)),  
        ('clf',   clf)
    ])
    print(f"Fitting multiclass pipeline for {name} …")
    pipe.fit(X_train, ymc_train)
    best_multi_models[name] = pipe

print("\nAll multiclass pipelines are now fitted and ready for feature‐importance extraction.")
# Out:
# Fitting multiclass pipeline for LogisticRegression …
# C:\Users\yanis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fitting multiclass pipeline for RandomForest …
# Fitting multiclass pipeline for XGBoost …
# C:\Users\yanis\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [02:31:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# All multiclass pipelines are now fitted and ready for feature‐importance extraction.

# %%
# ─── Cell 21: Binary Confusion Matrix Heatmap ────────────────────────────────
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# pick your best binary model (e.g. XGBoost)
pipe_bin = best_models['XGBoost']  

cm = confusion_matrix(yb_test, pipe_bin.predict(X_test))
plt.figure(figsize=(4,3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['No Lung','Lung'],
            yticklabels=['No Lung','Lung'])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Binary Confusion Matrix (XGBoost)")
plt.show()

# %%
# ─── Cell 22: Class‐Balance Bar Charts ───────────────────────────────────────
import seaborn as sns
import matplotlib.pyplot as plt

# (a) binary
plt.figure(figsize=(4,3))
sns.countplot(x=yb_test.map({0:'No Lung',1:'Lung'}))
plt.title("Binary Class Balance (Test set)")
plt.show()

# (b) multiclass
plt.figure(figsize=(6,3))
sns.countplot(x=ym_test)
plt.title("Multiclass Class Balance (Test set)")
plt.xticks(rotation=15)
plt.show()

# %%
# ─── Cell 23: Multiclass Confusion Matrix Heatmap ───────────────────────────
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# assume you've retrained pipe_multi on X_train, ym_train
pipe_multi = pipe  # replace with your fitted multiclass pipeline

cm2 = confusion_matrix(ym_test.codes, pipe_multi.predict(X_test))
labels = ['none','pneumonia','asthma','COPD']

plt.figure(figsize=(5,4))
sns.heatmap(cm2, annot=True, fmt='d', cmap='Oranges',
            xticklabels=labels, yticklabels=labels)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Multiclass Confusion Matrix")
plt.show()

# %%
# ─── Cell 24: Per‐Class ROC & Precision–Recall Curves (Multiclass) ─────────
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, precision_recall_curve, auc
from sklearn.preprocessing import label_binarize

# get probabilities and true one‑hot
y_score = pipe_multi.predict_proba(X_test)  # shape (n_samples,4)
y_true = label_binarize(ym_test.codes, classes=[0,1,2,3])

# ROC
plt.figure(figsize=(6,5))
for i, cls in enumerate(labels):
    fpr, tpr, _ = roc_curve(y_true[:,i], y_score[:,i])
    plt.plot(fpr, tpr, label=f"{cls} (AUC={auc(fpr,tpr):.2f})")
plt.plot([0,1],[0,1],'k--')
plt.xlabel("FPR"); plt.ylabel("TPR")
plt.title("Multiclass ROC Curves")
plt.legend(loc='lower right')
plt.show()

# Precision‑Recall
plt.figure(figsize=(6,5))
for i, cls in enumerate(labels):
    prec, rec, _ = precision_recall_curve(y_true[:,i], y_score[:,i])
    plt.plot(rec, prec, label=f"{cls} (AP={auc(rec,prec):.2f})")
plt.xlabel("Recall"); plt.ylabel("Precision")
plt.title("Multiclass Precision–Recall Curves")
plt.legend(loc='lower right')
plt.show()

# %%
# ─── Cell 25: Feature‐Importance for Binary Models ───────────────────────────
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# pull out feature names from your ColumnTransformer
feature_names = preprocessor.get_feature_names_out()

for name in ['LogisticRegression','RandomForest','XGBoost']:
    model = best_models[name]
    clf = model.named_steps['clf']

    if name=='LogisticRegression':
        # absolute coefficient
        imp = np.abs(clf.coef_[0])
    else:
        imp = clf.feature_importances_

    idx = np.argsort(imp)[::-1][:20]  # top‑20
    plt.figure(figsize=(6,4))
    sns.barplot(x=imp[idx], y=feature_names[idx])
    plt.title(f"Top Features: {name}")
    plt.xlabel("Importance")
    plt.tight_layout()
    plt.show()

# %%
# ─── Cell 26: Feature‐Importance Plots for Multiclass Models ────────────────
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# get feature names out of your preprocessor
feature_names = preprocessor.get_feature_names_out()

for name, pipe in best_multi_models.items():
    clf = pipe.named_steps['clf']
    
    if hasattr(clf, 'coef_'):
        # multiclass logistic: coef_.shape = (n_classes, n_features)
        # average absolute value across classes
        imp = np.abs(clf.coef_).mean(axis=0)
    else:
        # tree‐based: feature_importances_
        imp = clf.feature_importances_
    
    # pick top 20
    idx = np.argsort(imp)[::-1][:20]
    
    plt.figure(figsize=(6,4))
    sns.barplot(x=imp[idx], y=feature_names[idx])
    plt.title(f"Top‑20 Features (Multiclass) — {name}")
    plt.xlabel("Importance")
    plt.tight_layout()
    plt.show()

# %%
import os, pickle

os.makedirs("models", exist_ok=True)

with open("models/best_binary_xgb_pipeline.pkl","wb") as f:
    pickle.dump(best_models["XGBoost"], f)
with open("models/best_multiclass_xgb_pipeline.pkl","wb") as f:
    pickle.dump(best_multi_models["XGBoost"], f)
